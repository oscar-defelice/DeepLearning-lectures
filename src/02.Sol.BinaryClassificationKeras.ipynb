# %% [markdown]
# # Introduction to Deep Learning
#
# <p align="center">
#     <img width="699" alt="image" src="https://user-images.githubusercontent.com/49638680/159042792-8510fbd1-c4ac-4a48-8320-bc6c1a49cdae.png">
# </p>
#
# ---

# %% [markdown]
# # Deep Neural Network for Image Classification: Application
#
# We will build a deep network, and apply it to cat vs non-cat classification. Hopefully, you will see an improvement in accuracy relative to your previous logistic regression implementation.
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
#
# Let's get started!

# %%
# Import libraries
import time
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from utils.dnn_app_utils_v3 import *
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers
import pydotplus, pydot


import skimage.transform
import imageio

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)

# %% [markdown]
# ## The dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 10
plt.imshow(train_x_orig[index])
print ("y = " + str(train_y[0,index]) + ". It's a " + classes[train_y[0,index]].decode("utf-8") +  " picture.")
# Out:
# y = 0. It's a non-cat picture.

# %% [markdown]
# ## The model
#
# **Problem Statement**: How to create a neural network model in Keras?
#
# Well, there are several ways. Let's try to get familiar with a very intuitive one.
#
# ### A warm-up problem
#
# Before classifiyin a cat image, we can study a simpler problem: classify whether a patient may be result in having diabete. The dataset describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# Attributes are numeric valued, so we can feed a neural network directly with them.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv', header=None)
col_names = [   'NumberPregnant',
                'PlasmaGlucoseConc',
                'BloodPressure',
                'TricepsSkinThickness',
                'InsulinConc',
                'BMI',
                'DiabetesFunc',
                'Age',
                'Target']

df.columns = col_names

# %%
df
# Out:
#      NumberPregnant  PlasmaGlucoseConc  BloodPressure  TricepsSkinThickness  \
# 0                 6                148             72                    35
# 1                 1                 85             66                    29
# 2                 8                183             64                     0
# 3                 1                 89             66                    23
# 4                 0                137             40                    35
# ..              ...                ...            ...                   ...
# 763              10                101             76                    48
# 764               2                122             70                    27
# 765               5                121             72                    23
# 766               1                126             60                     0
# 767               1                 93             70                    31
#
#      InsulinConc   BMI  DiabetesFunc  Age  Target
# 0              0  33.6         0.627   50       1
# 1              0  26.6         0.351   31       0
# 2              0  23.3         0.672   32       1
# 3             94  28.1         0.167   21       0
# 4            168  43.1         2.288   33       1
# ..           ...   ...           ...  ...     ...
# 763          180  32.9         0.171   63       0
# 764            0  36.8         0.340   27       0
# 765          112  26.2         0.245   30       0
# 766            0  30.1         0.349   47       1
# 767            0  30.4         0.315   23       0
#
# [768 rows x 9 columns]

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
#
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the `input_dim` argument and setting it to $8$ for the $8$ input variables.
#
# > How do we know the number of layers and their types?
#
# This is a very hard question.
#
# __Here__: In this example, we will use a fully-connected network structure with three layers.

# %% [markdown]
# #### Activation Functions

# %% [markdown]
# Activation functions are functions used to get the output of a node
#
# ![](https://miro.medium.com/max/2724/1*E7ulOdTP-yekFGIJ8H8eVw.png)
#
# it must be __non-linear__, indeed one can prove that a very deep network is equivalent to just one-node network if you use only linear activation functions.
#
# __Commonly used activation functions__

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*p_hyqAtyI8pbt2kEl6siOQ.png)

# %% [markdown]
# **General notes**
#
# Briefly, functions that have a bit **flatter S** shape have better discriminatory power. The main reason why log-sigmoid and tanh are used is that their calculus derivatives, which are needed by the most common training algorithm back-propagation, are computationally convenient to compute.
#
# *For this problem*: we use a three-layers network, with `relu` activation for the first two layers' units, while `sigmoid` for the output layer.

# %%
model = Sequential(name = 'diabete_model')
model.add(Dense(units=12, input_dim=8, activation = 'relu', name = 'first_layer'))
model.add(Dense(units=5, activation = 'relu', name = 'second_layer'))
model.add(Dense(units=1, activation = 'sigmoid', name = 'output_layer'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Model: "diabete_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 12)                108
#
#  second_layer (Dense)        (None, 5)                 65
#
#  output_layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 179
# Trainable params: 179
# Non-trainable params: 0
# _________________________________________________________________
# 2022-06-28 14:28:17.612647: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-28 14:28:17.612778: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# You can also visualise the model on a picture.

# %%
plot_model(model,show_shapes=True, show_layer_names=True)

# %% [markdown]
# `None` is there to indicate the number of training examples.
# As one can see the model takes in a tensor of shape `(None, 8)`, since we have $8$ features.
#
# We are now ready to prepare data to be fed in the model.

# %%
# Transform data into array
X = df[df.columns[:8]].values
Y = df[df.columns[-1]].values.reshape(-1,1)

# %% [markdown]
# Split into train and test set

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.10, random_state=42)

X_val = X_train[:28]
Y_val = Y_train[:28]
X_train = X_train[28:]
Y_train = Y_train[28:]

# %% [markdown]
# <details>
# <summary> <strong> Batches, epochs what are these? </strong> </summary>
# <br>
# Here a <em>hyper-super-insufficient</em> note about batch size and epochs.
# I strongly encourage you to go and find details, starting from <a href="https://www.deeplearningbook.org/contents/optimization.html">here</a>.
#
# <h4> Batches </h4>
# First, what is a Batch?
#
# In principle you can pass the entire dataset into the neural net at once.
# This is not advisable.
#
# <p align="center">
#     <img src = "images/Batch-Man-image.png">
# </p>
#
# So, you divide dataset into a certain <em>Number of Batches</em> or sets or parts.
# <br>
# <strong>Note</strong>: Batch size and number of batches are two different things.
# <br>
# This allows you to update parameters (calculating gradients) over a small subset of the training one, speeding up computations.
# The cost function to minimise is a sum over the batch of single-example costs.
#
# $$ \mathcal{J}_b(\beta) = \sum_i^{N_b} J_i(\beta)\, .$$
#
# Hence the update is averaged over the batch, not over the whole dataset.
#
# There is of course a trade-off in the choice of the batch size ($N_b$). Too large makes you lose the effect of speeding up the computations (and evantually it may overfill the memory). Too small make the training too "noisy".
#
# <p align="center">
#     <img src = "https://miro.medium.com/max/908/1*bKSddSmLDaYszWllvQ3Z6A.png">
# </p>
#
# <h4> Epochs </h4>
#
# <blockquote>One Epoch is when an ENTIRE dataset is passed forward and backward through the neural network only ONCE. </blockquote>
#
# As said, since one epoch is often too big to feed to the computer at once we divide it in several smaller batches.
# <br>
# Why we use more than one Epoch? Since generally deep learning algorithms have a great number of parameters to fit, passing the entire dataset through a neural network once may be not enough. Hence, we need to pass the full dataset multiple times to the same neural network. But keep in mind that we are using a limited dataset and to optimise the learning and the graph we are using Gradient Descent which is an iterative process. So, updating the weights with single pass or one epoch is not enough.
# <br>
# As the number of epochs increases, more number of times the weight are changed in the neural network and the curve goes from underfitting to optimal to overfitting curve.
# <br>
# So, what is the right numbers of epochs? Unfortunately, there is no right answer to this question. As usual, there is a trade-off.
#
# </details>

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="logs")

print('# Fit model on training data')
history = model.fit(X_train, Y_train,
                    batch_size=10,
                    epochs=150,
                    # We pass some validation for
                    # monitoring validation loss and metrics
                    # at the end of each epoch
                    validation_data=(X_val, Y_val),
                    callbacks = [tensorboard_callback])

print('\nhistory dict:', history.history)
# Out:
# # Fit model on training data
# Epoch 1/150
# 2022-06-28 14:28:21.689738: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-28 14:28:21.882085: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 67/67 [==============================] - 1s 10ms/step - loss: 9.9231 - accuracy: 0.6335 - val_loss: 2.8905 - val_accuracy: 0.6429
# Epoch 2/150
# 10/67 [===>..........................] - ETA: 0s - loss: 3.1394 - accuracy: 0.6200
# 2022-06-28 14:28:22.597987: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 67/67 [==============================] - 0s 6ms/step - loss: 2.6021 - accuracy: 0.5988 - val_loss: 1.8001 - val_accuracy: 0.6429
# Epoch 3/150
# 67/67 [==============================] - 0s 7ms/step - loss: 1.5223 - accuracy: 0.6063 - val_loss: 1.0336 - val_accuracy: 0.6786
# Epoch 4/150
# 67/67 [==============================] - 0s 7ms/step - loss: 1.0431 - accuracy: 0.6214 - val_loss: 0.7599 - val_accuracy: 0.6786
# Epoch 5/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.8863 - accuracy: 0.6078 - val_loss: 0.6940 - val_accuracy: 0.7500
# Epoch 6/150
# 67/67 [==============================] - 0s 7ms/step - loss: 0.7446 - accuracy: 0.6305 - val_loss: 0.6284 - val_accuracy: 0.7500
# Epoch 7/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.7088 - accuracy: 0.6154 - val_loss: 0.6831 - val_accuracy: 0.7143
# Epoch 8/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6847 - accuracy: 0.6531 - val_loss: 0.6319 - val_accuracy: 0.7500
# Epoch 9/150
# 67/67 [==============================] - 0s 7ms/step - loss: 0.6761 - accuracy: 0.6229 - val_loss: 0.7572 - val_accuracy: 0.6786
# Epoch 10/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6609 - accuracy: 0.6712 - val_loss: 0.5947 - val_accuracy: 0.6071
# Epoch 11/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6396 - accuracy: 0.6471 - val_loss: 0.6041 - val_accuracy: 0.7143
# Epoch 12/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6378 - accuracy: 0.6516 - val_loss: 0.6508 - val_accuracy: 0.6786
# Epoch 13/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6327 - accuracy: 0.6561 - val_loss: 0.5709 - val_accuracy: 0.6786
# Epoch 14/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6167 - accuracy: 0.6410 - val_loss: 0.5740 - val_accuracy: 0.6071
# Epoch 15/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6265 - accuracy: 0.6576 - val_loss: 0.6227 - val_accuracy: 0.6786
# Epoch 16/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6124 - accuracy: 0.6637 - val_loss: 0.6126 - val_accuracy: 0.7143
# Epoch 17/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6027 - accuracy: 0.6848 - val_loss: 0.5890 - val_accuracy: 0.5000
# Epoch 18/150
# 67/67 [==============================] - 0s 6ms/step - loss: 0.

#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# #### Predictions
#
# The number one question I get asked is:
#
# > After I train my model, how can I use it to make predictions on new data?
#
# this is a great question.

# %%
# make probability predictions with the model
new_patient = np.array([4.00e+00, 1.48e+02, 6.00e+01, 2.70e+01, 3.18e+02, 3.09e+01,
       1.50e-01, 2.90e+01]).reshape(1,-1)

prob_pred = model.predict(new_patient)

prediction = round(float(prob_pred[[0]]))
# Out:
# 2022-06-28 10:24:11.128968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 256ms/step

# %%
prob_pred
# Out:
# array([[0.47349325]], dtype=float32)

# %% [markdown]
# ## Back to cats

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %%
# Explore your dataset 
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(train_x_orig.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x_orig shape: " + str(test_x_orig.shape))
print ("test_y shape: " + str(test_y.shape))
# Out:
# Number of training examples: 209
# Number of testing examples: 50
# Each image is of size: (64, 64, 3)
# train_x_orig shape: (209, 64, 64, 3)
# train_y shape: (1, 209)
# test_x_orig shape: (50, 64, 64, 3)
# test_y shape: (1, 50)

# %% [markdown]
# As usual, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# <img src="images/imvectorkiank.png" style="width:450px;height:300px;">
#
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# Standardize data to have feature values between 0 and 1.
train_x = (train_x_flatten/255.)
test_x = (test_x_flatten/255.)

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)

# %% [markdown]
# $12,288$ equals $64 \times 64 \times 3$ which is the size of one reshaped image vector.

# %% [markdown]
# ## The model

# %% [markdown]
# Now that you are familiar with the dataset, it is time to build a deep neural network to distinguish cat images from non-cat images.
#
# You will build two different models:
# - A 2-layer neural network
# - An L-layer deep neural network
#
# You will then compare the performance of these models, and also try out different values for $L$.
#
# Let's look at the two architectures.
#
# ### 2-layer neural network
#
# <img src="images/2layerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 2</u>: 2-layer neural network. <br> The model can be summarized as: ***INPUT -> LINEAR -> RELU -> LINEAR -> SIGMOID -> OUTPUT***. </center></caption>
#
# <u>Detailed Architecture of figure 2</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size $(12288,1)$.
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ of size $(n^{[1]}, 12288)$.
# - You then add a bias term and take its relu to get the following vector: $[a_0^{[1]}, a_1^{[1]},..., a_{n^{[1]}-1}^{[1]}]^T$.
# - You then repeat the same process.
# - You multiply the resulting vector by $W^{[2]}$ and add your intercept (bias).
# - Finally, you take the sigmoid of the result. If it is greater than 0.5, you classify it to be a cat.
#
# ###  L-layer deep neural network
#
# It is hard to represent an L-layer deep neural network with the above representation. However, here is a simplified network representation:
#
# <img src="images/LlayerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 3</u>: L-layer neural network. <br> The model can be summarized as: ***[LINEAR -> RELU] $\times$ (L-1) -> LINEAR -> SIGMOID***</center></caption>
#
# <u>Detailed Architecture of figure 3</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size (12288,1).
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ and then you add the intercept $b^{[1]}$. The result is called the linear unit.
# - Next, you take the relu of the linear unit. This process could be repeated several times for each $(W^{[l]}, b^{[l]})$ depending on the model architecture.
# - Finally, you take the sigmoid of the final linear unit. If it is greater than 0.5, you classify it to be a cat.
#
# ### 3.3 - General methodology
#
# As usual you will follow the Keras/Deep Learning methodology to build the model:
#     1. Design the shape of your model
#     2. Add layers to your `Sequential model`
#     3. Train the parameters on the training set
#     4. Use learnt parameters to make predictions on new data.
#
# Let's now implement those two models!

# %%
n_x = 12288     # num_px * num_px * 3

# %%
def two_layer_model(n_units_1, n_units_2 = 1):
    """
        function to define a two-layer neural network model.
        
        Parameters:
        ----------
            - n_units_1 : int
                            number of hidden units of the first hidden layer.
                            
            - n_units_2 : int
                            number of hidden units of the second hidden layer.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units_1, input_dim=n_x, activation = 'tanh', kernel_initializer='uniform', name = 'first_hidden_layer'))
    model.add(Dense(n_units_2, activation = 'sigmoid', name = 'output_layer'))
    
    return model

# %%
model = two_layer_model(7)

# %%
opt = optimizers.Adam(lr = 1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_hidden_layer (Dense)  (None, 7)                 86023
#
#  output_layer (Dense)        (None, 1)                 8
#
# =================================================================
# Total params: 86,031
# Trainable params: 86,031
# Non-trainable params: 0
# _________________________________________________________________
# /Users/oscardefelice/miniconda3/envs/dl_lectures/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
train_y = train_y.T

# %%
model.fit(train_x, train_y, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 2022-06-28 10:24:23.944342: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 21/21 [==============================] - 1s 7ms/step - loss: 0.7307 - accuracy: 0.5455
# Epoch 2/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6431 - accuracy: 0.6124
# Epoch 3/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6420 - accuracy: 0.6507
# Epoch 4/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6329 - accuracy: 0.6603
# Epoch 5/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6248 - accuracy: 0.6507
# Epoch 6/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6459
# Epoch 7/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6192 - accuracy: 0.6459
# Epoch 8/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.6459
# Epoch 9/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6110 - accuracy: 0.6603
# Epoch 10/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6069 - accuracy: 0.6603
# Epoch 11/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6043 - accuracy: 0.6651
# Epoch 12/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.6037 - accuracy: 0.6699
# Epoch 13/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5964 - accuracy: 0.6699
# Epoch 14/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5952 - accuracy: 0.6699
# Epoch 15/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5934 - accuracy: 0.6746
# Epoch 16/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5895 - accuracy: 0.6890
# Epoch 17/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5860 - accuracy: 0.6890
# Epoch 18/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5833 - accuracy: 0.6890
# Epoch 19/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5813 - accuracy: 0.6842
# Epoch 20/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5787 - accuracy: 0.7033
# Epoch 21/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5763 - accuracy: 0.6938
# Epoch 22/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5737 - accuracy: 0.6986
# Epoch 23/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5730 - accuracy: 0.6938
# Epoch 24/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5685 - accuracy: 0.6986
# Epoch 25/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5654 - accuracy: 0.7033
# Epoch 26/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5625 - accuracy: 0.6986
# Epoch 27/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5611 - accuracy: 0.6986
# Epoch 28/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5599 - accuracy: 0.7129
# Epoch 29/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5557 - accuracy: 0.6986
# Epoch 30/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5580 - accuracy: 0.7273
# Epoch 31/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5509 - accuracy: 0.7033
# Epoch 32/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5496 - accuracy: 0.6938
# Epoch 33/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.7177
# Epoch 34/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5430 - accuracy: 0.7177
# Epoch 35/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5441 - accuracy: 0.7081
# Epoch 36/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5403 - accuracy: 0.7177
# Epoch 37/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5397 - accuracy: 0.7225
# Epoch 38/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5361 - accuracy: 0.7273
# Epoch 39/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5374 - accuracy: 0.7273
# Epoch 40/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5318 - accuracy: 0.7321
# Epoch 41/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5301 - accuracy: 0.7416
# Epoch 42/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5275 - accuracy: 0.7368
# Epoch 43/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5282 - accuracy: 0.7416
# Epoch 44/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5245 - accuracy: 0.7416
# Epoch 45/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5244 - accuracy: 0.7464
# Epoch 46/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5205 - accuracy: 0.7321
# Epoch 47/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5219 - accuracy: 0.7368
# Epoch 48/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5155 - accuracy: 0.7560
# Epoch 49/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5146 - accuracy: 0.7656
# Epoch 50/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7512
# Epoch 51/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.7751
# Epoch 52/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5137 - accuracy: 0.7464
# Epoch 53/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7751
# Epoch 54/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7608
# Epoch 55/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.5028 - accuracy: 0.7799
# Epoch 56/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4996 - accuracy: 0.7703
# Epoch 57/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4990 - accuracy: 0.7608
# Epoch 58/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4956 - accuracy: 0.7751
# Epoch 59/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4948 - accuracy: 0.8038
# Epoch 60/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4921 - accuracy: 0.7895
# Epoch 61/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4902 - accuracy: 0.7943
# Epoch 62/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4888 - accuracy: 0.8086
# Epoch 63/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4886 - accuracy: 0.7943
# Epoch 64/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4843 - accuracy: 0.7943
# Epoch 65/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4838 - accuracy: 0.7943
# Epoch 66/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.7990
# Epoch 67/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.8134
# Epoch 68/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4769 - accuracy: 0.7943
# Epoch 69/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4740 - accuracy: 0.7943
# Epoch 70/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4728 - accuracy: 0.7990
# Epoch 71/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4720 - accuracy: 0.7895
# Epoch 72/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4697 - accuracy: 0.8086
# Epoch 73/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4704 - accuracy: 0.8182
# Epoch 74/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4669 - accuracy: 0.7799
# Epoch 75/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4674 - accuracy: 0.8182
# Epoch 76/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4615 - accuracy: 0.8182
# Epoch 77/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4613 - accuracy: 0.7943
# Epoch 78/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4570 - accuracy: 0.8182
# Epoch 79/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4566 - accuracy: 0.8325
# Epoch 80/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.8134
# Epoch 81/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4556 - accuracy: 0.8230
# Epoch 82/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4510 - accuracy: 0.8182
# Epoch 83/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4489 - accuracy: 0.8134
# Epoch 84/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4518 - accuracy: 0.8134
# Epoch 85/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4486 - accuracy: 0.8086
# Epoch 86/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4444 - accuracy: 0.8086
# Epoch 87/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.8182
# Epoch 88/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.8230
# Epoch 89/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4415 - accuracy: 0.8086
# Epoch 90/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4398 - accuracy: 0.8134
# Epoch 91/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4431 - accuracy: 0.8182
# Epoch 92/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4353 - accuracy: 0.8325
# Epoch 93/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4362 - accuracy: 0.8182
# Epoch 94/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4330 - accuracy: 0.8230
# Epoch 95/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4325 - accuracy: 0.8325
# Epoch 96/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4301 - accuracy: 0.8421
# Epoch 97/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4308 - accuracy: 0.8278
# Epoch 98/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4280 - accuracy: 0.8373
# Epoch 99/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4281 - accuracy: 0.8469
# Epoch 100/100
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4264 - accuracy: 0.8134

# %%
# Predictions on test set
model.predict(test_x)
# Out:
# 2/2 [==============================] - 0s 9ms/step
# 2022-06-28 10:24:41.687256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# array([[0.54374516],
#        [0.41695648],
#        [0.6571479 ],
#        [0.63516843],
#        [0.52642053],
#        [0.40467435],
#        [0.3472942 ],
#        [0.49921766],
#        [0.68367815],
#        [0.3934489 ],
#        [0.34809595],
#        [0.41769156],
#        [0.6732263 ],
#        [0.520989  ],
#        [0.20541014],
#        [0.5998741 ],
#        [0.12788257],
#        [0.5041488 ],
#        [0.31157285],
#        [0.14692257],
#        [0.6014276 ],
#        [0.14555375],
#        [0.09469274],
#        [0.3131011 ],
#        [0.678663  ],
#        [0.84758973],
#        [0.33254993],
#        [0.17042011],
#        [0.4521484 ],
#        [0.50465673],
#        [0.49045965],
#        [0.5041791 ],
#        [0.5942276 ],
#        [0.44845378],
#        [0.6928342 ],
#        [0.23033579],
#        [0.22508977],
#        [0.56510615],
#        [0.6164448 ],
#        [0.14286217],
#        [0.41075876],
#        [0.4927648 ],
#        [0.25091258],
#        [0.17941661],
#        [0.48328024],
#        [0.31344953],
#        [0.43025056],
#        [0.6204402 ],
#        [0.55021125],
#        [0.17896435]], dtype=float32)

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6397 - accuracy: 0.5800
#
# # Evaluate
# 2022-06-28 10:24:44.079322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# {'loss': 0.6396629214286804, 'accuracy': 0.5799999833106995}

# %% [markdown]
# ### L-layer model

# %%
def L_layer_model(n_layers, n_units, n_x):
    """
        function to define an L-layer neural network model.
        
        Parameters:
        ----------
            - n_layers : int
                            number of hidden layers + output layer.
                            
            - n_units :  list of int
                            number of hidden units of for each hidden layer.
                            
            - n_x : int
                        number of input features.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units[0], input_dim = n_x, activation = 'relu',  kernel_initializer='uniform')) # first layer
    for l in range(1,n_layers):
        if l == n_layers-1:
            model.add(Dropout(rate=0.2))
            model.add(Dense(n_units[l], activation = 'sigmoid', name = 'output_layer')) # output layer
        else:
            model.add(Dense(n_units[l], activation = 'relu', name = 'hidden_layer_' + str(l)))
        
    return model

# %%
n_layers = 3
n_units = [17, 7, 1]

model = L_layer_model(n_layers, n_units, n_x)

# %%
opt = optimizers.Adam(lr=1e-4)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 17)                208913
#
#  hidden_layer_1 (Dense)      (None, 7)                 126
#
#  dropout (Dropout)           (None, 7)                 0
#
#  output_layer (Dense)        (None, 1)                 8
#
# =================================================================
# Total params: 209,047
# Trainable params: 209,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_x, train_y, batch_size=32, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
#
100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3476 - accuracy: 0.8862 - val_loss: 0.6626 - val_accuracy: 0.5714
# Epoch 61/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3543 - accuracy: 0.8383 - val_loss: 0.6934 - val_accuracy: 0.5714
# Epoch 62/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.8503 - val_loss: 0.6873 - val_accuracy: 0.5476
# Epoch 63/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3467 - accuracy: 0.8623 - val_loss: 0.6848 - val_accuracy: 0.5476
# Epoch 64/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3548 - accuracy: 0.8683 - val_loss: 0.6494 - val_accuracy: 0.5714
# Epoch 65/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3441 - accuracy: 0.8922 - val_loss: 0.7038 - val_accuracy: 0.5476
# Epoch 66/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3630 - accuracy: 0.8084 - val_loss: 0.6842 - val_accuracy: 0.5476
# Epoch 67/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3373 - accuracy: 0.8982 - val_loss: 0.6766 - val_accuracy: 0.5714
# Epoch 68/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3323 - accuracy: 0.8862 - val_loss: 0.6937 - val_accuracy: 0.5476
# Epoch 69/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3260 - accuracy: 0.8623 - val_loss: 0.6890 - val_accuracy: 0.5476
# Epoch 70/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3253 - accuracy: 0.8862 - val_loss: 0.6969 - val_accuracy: 0.5476
# Epoch 71/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3100 - accuracy: 0.8982 - val_loss: 0.6866 - val_accuracy: 0.5476
# Epoch 72/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3021 - accuracy: 0.8922 - val_loss: 0.6973 - val_accuracy: 0.5476
# Epoch 73/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3077 - accuracy: 0.8922 - val_loss: 0.6609 - val_accuracy: 0.5476
# Epoch 74/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3021 - accuracy: 0.8922 - val_loss: 0.7152 - val_accuracy: 0.5476
# Epoch 75/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3185 - accuracy: 0.8623 - val_loss: 0.7210 - val_accuracy: 0.5476
# Epoch 76/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3174 - accuracy: 0.8982 - val_loss: 0.6989 - val_accuracy: 0.5714
# Epoch 77/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2995 - accuracy: 0.8922 - val_loss: 0.7318 - val_accuracy: 0.5476
# Epoch 78/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3047 - accuracy: 0.8862 - val_loss: 0.7037 - val_accuracy: 0.5476
# Epoch 79/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3006 - accuracy: 0.8982 - val_loss: 0.7421 - val_accuracy: 0.5476
# Epoch 80/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2992 - accuracy: 0.8982 - val_loss: 0.7065 - val_accuracy: 0.5476
# Epoch 81/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2980 - accuracy: 0.9042 - val_loss: 0.7296 - val_accuracy: 0.5476
# Epoch 82/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2973 - accuracy: 0.9162 - val_loss: 0.7219 - val_accuracy: 0.5476
# Epoch 83/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3101 - accuracy: 0.8683 - val_loss: 0.7619 - val_accuracy: 0.5476
# Epoch 84/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2883 - accuracy: 0.9042 - val_loss: 0.7676 - val_accuracy: 0.5476
# Epoch 85/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2832 - accuracy: 0.9042 - val_loss: 0.7139 - val_accuracy: 0.5476
# Epoch 86/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3118 - accuracy: 0.8683 - val_loss: 0.7103 - val_accuracy: 0.5476
# Epoch 87/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2675 - accuracy: 0.9222 - val_loss: 0.7405 - val_accuracy: 0.5476
# Epoch 88/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2571 - accuracy: 0.9341 - val_loss: 0.7669 - val_accuracy: 0.5476
# Epoch 89/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2914 - accuracy: 0.8802 - val_loss: 0.7592 - val_accuracy: 0.5476
# Epoch 90/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2765 - accuracy: 0.9042 - val_loss: 0.7533 - val_accuracy: 0.5476
# Epoch 91/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2725 - accuracy: 0.9162 - val_loss: 0.7251 - val_accuracy: 0.5476
# Epoch 92/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2894 - accuracy: 0.9222 - val_loss: 0.7247 - val_accuracy: 0.5476
# Epoch 93/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2764 - accuracy: 0.8982 - val_loss: 0.7328 - val_accuracy: 0.5476
# Epoch 94/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2642 - accuracy: 0.9341 - val_loss: 0.7385 - val_accuracy: 0.5476
# Epoch 95/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2814 - accuracy: 0.9042 - val_loss: 0.7428 - val_accuracy: 0.5476
# Epoch 96/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2682 - accuracy: 0.9162 - val_loss: 0.7397 - val_accuracy: 0.5714
# Epoch 97/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2472 - accuracy: 0.9521 - val_loss: 0.7841 - val_accuracy: 0.5714
# Epoch 98/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2533 - accuracy: 0.9401 - val_loss: 0.7235 - val_accuracy: 0.5476
# Epoch 99/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2354 - accuracy: 0.9401 - val_loss: 0.7679 - val_accuracy: 0.5714
# Epoch 100/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2657 - accuracy: 0.9042 - val_loss: 0.7091 - val_accuracy: 0.5238

# %% [markdown]
# ## Learning Curves

# %% [markdown]
# __Question__: How to use Learning Curves to Diagnose Machine Learning Model Performance?

# %% [markdown]
# This lecture aim is to define and study an important tool for diagnostic of a machine learning algorithm: __learning curves__.
#
# > A learning curve is a plot of model learning performance over experience or time.
#
# In other words, one can say that _Learning Curves_ provide a mathematical representation of the learning process that takes place as task repetition occurs.

# %% [markdown]
# The model can be evaluated on the training dataset and on a hold out validation dataset after each update during training and plots of the measured performance can created to show learning curves.
#
# Reviewing learning curves of models during training can be used to diagnose problems with learning, such as an underfit or overfit model, as well as whether the training and validation datasets are suitably representative.

# %% [markdown]
# An interesting, but quite technical, reading may be found [here](https://www.sciencedirect.com/science/article/abs/pii/S016981411100062X).

# %% [markdown]
# First of all we need to choose a way to parametrise the learning performance.
# This is done through a metric. One can be, for instance, the learning accuracy, or precision, etc.

# %%
print(history.history.keys())

plt.figure(figsize=(15,10))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.figure(figsize=(15,10))
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7295 - accuracy: 0.7200
#
# # Evaluate
# {'loss': 0.7294530868530273, 'accuracy': 0.7199999690055847}

# %% [markdown]
# You obtained a classifier for cat picture with a $70$% accuracy.

# %% [markdown]
# ## Test with your picture

# %%
my_image = "Giampiero.jpeg" # change this to the name of your image file 
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)

fname = "images/" + my_image
image = np.array(imageio.imread(fname))
image = image/255.
my_image = skimage.transform.resize(image, (num_px,num_px)).reshape((1, num_px*num_px*3))
my_predicted_image = model.predict(my_image)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.round(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# 1/1 [==============================] - 0s 138ms/step
# 2022-06-28 10:25:12.439940: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# y = 0.56137985, your L-layer model predicts a "cat" picture.
