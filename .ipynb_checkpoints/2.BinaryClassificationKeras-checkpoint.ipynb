# %% [markdown]
# ![](https://www.domsoria.com/wp-content/uploads/2019/11/keras.png)

# %% [markdown]
# # Deep Neural Network for Image Classification: Application
#
# We will build a deep network, and apply it to cat vs non-cat classification. Hopefully, you will see an improvement in accuracy relative to your previous logistic regression implementation.
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
#
# Let's get started!

# %%
# Import libraries
import time
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from utils.dnn_app_utils_v3 import *
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import plot_model
from keras import optimizers


import skimage
import imageio

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## The dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 10
plt.imshow(train_x_orig[index])
print ("y = " + str(train_y[0,index]) + ". It's a " + classes[train_y[0,index]].decode("utf-8") +  " picture.")
# Out:
# y = 0. It's a non-cat picture.

# %% [markdown]
# ## The model
#
# **Problem Statement**: How to create a neural network model in Keras?
#
# Well, there are several ways. Let's try to get familiar with a very intuitive one.
#
# ### A warm-up problem
#
# Before classifiyin a cat image, we can study a simpler problem: classify whether a patient may be result in having diabete. The dataset describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# Attributes are numeric valued, so we can feed a neural network directly with them.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv', header=None)
col_names = [   'NumberPregnant',
                'PlasmaGlucoseConc',
                'BloodPressure',
                'TricepsSkinThickness',
                'InsulinConc',
                'BMI',
                'DiabetesFunc',
                'Age',
                'Target']

df.columns = col_names

# %%
df
# Out:
#      NumberPregnant  PlasmaGlucoseConc  BloodPressure  TricepsSkinThickness  \
# 0                 6                148             72                    35
# 1                 1                 85             66                    29
# 2                 8                183             64                     0
# 3                 1                 89             66                    23
# 4                 0                137             40                    35
# ..              ...                ...            ...                   ...
# 763              10                101             76                    48
# 764               2                122             70                    27
# 765               5                121             72                    23
# 766               1                126             60                     0
# 767               1                 93             70                    31
#
#      InsulinConc   BMI  DiabetesFunc  Age  Target
# 0              0  33.6         0.627   50       1
# 1              0  26.6         0.351   31       0
# 2              0  23.3         0.672   32       1
# 3             94  28.1         0.167   21       0
# 4            168  43.1         2.288   33       1
# ..           ...   ...           ...  ...     ...
# 763          180  32.9         0.171   63       0
# 764            0  36.8         0.340   27       0
# 765          112  26.2         0.245   30       0
# 766            0  30.1         0.349   47       1
# 767            0  30.4         0.315   23       0
#
# [768 rows x 9 columns]

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
#
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the `input_dim` argument and setting it to $8$ for the $8$ input variables.
#
# > How do we know the number of layers and their types?
#
# This is a very hard question.
#
# __Here__: In this example, we will use a fully-connected network structure with three layers.

# %% [markdown]
# #### Activation Functions

# %% [markdown]
# Activation functions are functions used to get the output of a node
#
# ![](https://miro.medium.com/max/2724/1*E7ulOdTP-yekFGIJ8H8eVw.png)
#
# it must be __non-linear__, indeed one can prove that a very deep network is equivalent to just one-node network if you use only linear activation functions.
#
# __Commonly used activation functions__

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*p_hyqAtyI8pbt2kEl6siOQ.png)

# %% [markdown]
# **General notes**
#
# Briefly, functions that have a bit **flatter S** shape have better discriminatory power. The main reason why log-sigmoid and tanh are used is that their calculus derivatives, which are needed by the most common training algorithm back-propagation, are computationally convenient to compute.
#
# *For this problem*: we use a three-layers network, with `relu` activation for the first two layers' units, while `sigmoid` for the output layer.

# %%
model = Sequential(name = 'diabete_model')
model.add(Dense(units=12, input_dim=8, activation = 'relu', name = 'first_layer'))
model.add(Dense(units=5, activation = 'relu', name = 'second_layer'))
model.add(Dense(units=1, activation = 'sigmoid', name = 'output_layer'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "diabete_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# first_layer (Dense)          (None, 12)                108
# _________________________________________________________________
# second_layer (Dense)         (None, 5)                 65
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 6
# =================================================================
# Total params: 179
# Trainable params: 179
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# You can also visualise the model on a picture.

# %%
plot_model(model,show_shapes=True, show_layer_names=True, to_file='model.png')

# %% [markdown]
# `None` is there to indicate the number of training examples.
# As one can see the model takes in a tensor of shape `(None, 8)`, since we have $8$ features.
#
# We are now ready to prepare data to be fed in the model.

# %%
# Transform data into array
X = df[df.columns[:8]].values
Y = df[df.columns[-1]].values.reshape(-1,1)

# %% [markdown]
# Split into train and test set

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.10, random_state=42)

X_val = X_train[:28]
Y_val = Y_train[:28]
X_train = X_train[28:]
Y_train = Y_train[28:]

# %%
print('# Fit model on training data')
history = model.fit(X_train, Y_train,
                    batch_size=10,
                    epochs=150,
                    # We pass some validation for
                    # monitoring validation loss and metrics
                    # at the end of each epoch
                    validation_data=(X_val, Y_val))

print('\nhistory dict:', history.history)
# Out:
# # Fit model on training data
# Train on 663 samples, validate on 28 samples
# Epoch 1/150
# 663/663 [==============================] - 0s 750us/step - loss: 26.5384 - accuracy: 0.6516 - val_loss: 11.1636 - val_accuracy: 0.7143
# Epoch 2/150
# 663/663 [==============================] - 0s 120us/step - loss: 8.9022 - accuracy: 0.6305 - val_loss: 4.3665 - val_accuracy: 0.6071
# Epoch 3/150
# 663/663 [==============================] - 0s 103us/step - loss: 3.6505 - accuracy: 0.6078 - val_loss: 1.9986 - val_accuracy: 0.6071
# Epoch 4/150
# 663/663 [==============================] - 0s 103us/step - loss: 1.8967 - accuracy: 0.5671 - val_loss: 1.7967 - val_accuracy: 0.4286
# Epoch 5/150
# 663/663 [==============================] - 0s 105us/step - loss: 1.5655 - accuracy: 0.5309 - val_loss: 1.4876 - val_accuracy: 0.5357
# Epoch 6/150
# 663/663 [==============================] - 0s 106us/step - loss: 1.3934 - accuracy: 0.5626 - val_loss: 1.3420 - val_accuracy: 0.5000
# Epoch 7/150
# 663/663 [==============================] - 0s 113us/step - loss: 1.3517 - accuracy: 0.5716 - val_loss: 1.2150 - val_accuracy: 0.5000
# Epoch 8/150
# 663/663 [==============================] - 0s 108us/step - loss: 1.2049 - accuracy: 0.5747 - val_loss: 1.0870 - val_accuracy: 0.5714
# Epoch 9/150
# 663/663 [==============================] - 0s 117us/step - loss: 1.1275 - accuracy: 0.5777 - val_loss: 1.1441 - val_accuracy: 0.5357
# Epoch 10/150
# 663/663 [==============================] - 0s 141us/step - loss: 1.0378 - accuracy: 0.5747 - val_loss: 0.9690 - val_accuracy: 0.5357
# Epoch 11/150
# 663/663 [==============================] - 0s 152us/step - loss: 0.9961 - accuracy: 0.5777 - val_loss: 0.9852 - val_accuracy: 0.5714
# Epoch 12/150
# 663/663 [==============================] - 0s 120us/step - loss: 0.9766 - accuracy: 0.5837 - val_loss: 1.0929 - val_accuracy: 0.5357
# Epoch 13/150
# 663/663 [==============================] - 0s 119us/step - loss: 0.9551 - accuracy: 0.5747 - val_loss: 0.8621 - val_accuracy: 0.6071
# Epoch 14/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.9156 - accuracy: 0.5837 - val_loss: 0.8196 - val_accuracy: 0.5357
# Epoch 15/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.8930 - accuracy: 0.6003 - val_loss: 0.7871 - val_accuracy: 0.5357
# Epoch 16/150
# 663/663 [==============================] - 0s 122us/step - loss: 0.8821 - accuracy: 0.6003 - val_loss: 0.9439 - val_accuracy: 0.4643
# Epoch 17/150
# 663/663 [==============================] - 0s 124us/step - loss: 0.8868 - accuracy: 0.5958 - val_loss: 0.7692 - val_accuracy: 0.6429
# Epoch 18/150
# 663/663 [==============================] - 0s 93us/step - loss: 0.7905 - accuracy: 0.6154 - val_loss: 0.8955 - val_accuracy: 0.5714
# Epoch 19/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.8083 - accuracy: 0.5928 - val_loss: 0.7011 - val_accuracy: 0.6071
# Epoch 20/150
# 663/663 [==============================] - 0s 118us/step - loss: 0.7848 - accuracy: 0.6169 - val_loss: 0.6818 - val_accuracy: 0.6071
# Epoch 21/150
# 663/663 [==============================] - 0s 128us/step - loss: 0.7510 - accuracy: 0.6229 - val_loss: 0.7097 - val_accuracy: 0.5714
# Epoch 22/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.7474 - accuracy: 0.6365 - val_loss: 0.6599 - val_accuracy: 0.6786
# Epoch 23/150
# 663/663 [==============================] - 0s 110us/step - loss: 0.7978 - accuracy: 0.6335 - val_loss: 0.7007 - val_accuracy: 0.5714
# Epoch 24/150
# 663/663 [==============================] - 0s 110us/step - loss: 0.7292 - accuracy: 0.6305 - val_loss: 0.6546 - val_accuracy: 0.5714
# Epoch 25/150
# 663/663 [==============================] - 0s 111us/step - loss: 0.7318 - accuracy: 0.6229 - val_loss: 0.6595 - val_accuracy: 0.6071
# Epoch 26/150
# 663/663 [==============================] - 0s 132us/step - loss: 0.7283 - accuracy: 0.6139 - val_loss: 0.6579 - val_accuracy: 0.6786
# Epoch 27/150
# 663/663 [==============================] - 0s 122us/step - loss: 0.6865 - accuracy: 0.6440 - val_loss: 0.6491 - val_accuracy: 0.6786
# Epoch 28/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.6859 - accuracy: 0.6531 - val_loss: 0.6439 - val_accuracy: 0.7143
# Epoch 29/150
# 663/663 [==============================] - 0s 105us/step - loss: 0.6858 - accuracy: 0.6410 - val_loss: 0.6360 - val_accuracy: 0.6429
# Epoch 30/150
# 663/663 [==============================] - 0s 108us/step - loss: 0.6547 - accuracy: 0.6591 - val_loss: 0.6332 - val_accuracy: 0.7143
# Epoch 31/150
# 663/663 [==============================] - 0s 105us/step - loss: 0.7044 - accuracy: 0.6229 - val_loss: 0.6129 - val_accuracy: 0.7500
# Epoch 32/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.6404 - accuracy: 0.6531 - val_loss: 0.6562 - val_accuracy: 0.6429
# Epoch 33/150
# 663/663 [==============================] - 0s 111us/step - loss: 0.7207 - accuracy: 0.6546 - val_loss: 0.6755 - val_accuracy: 0.6429
# Epoch 34/150
# 663/663 [==============================] - 0s 135us/step - loss: 0.6544 - accuracy: 0.6697 - val_loss: 0.6125 - val_accuracy: 0.7143
# Epoch 35/150
# 663/663 [==============================] - 0s 144us/step - loss: 0.6262 - accuracy: 0.6787 - val_loss: 0.6058 - val_accuracy: 0.7143
# Epoch 36/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.6245 - accuracy: 0.6878 - val_loss: 0.6030 - val_accuracy: 0.8571
# Epoch 37/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.6178 - accuracy: 0.6787 - val_loss: 0.6033 - val_accuracy: 0.7857
# Epoch 38/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.6308 - accuracy: 0.6742 - val_loss: 0.6213 - val_accuracy: 0.6786
# Epoch 39/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5981 - accuracy: 0.6863 - val_loss: 0.6005 - val_accuracy: 0.7143
# Epoch 40/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.6101 - accuracy: 0.6637 - val_loss: 0.6161 - val_accuracy: 0.7857
# Epoch 41/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.5889 - accuracy: 0.6938 - val_loss: 0.6216 - val_accuracy: 0.6786
# Epoch 42/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5850 - accuracy: 0.7014 - val_loss: 0.5851 - val_accuracy: 0.8571
# Epoch 43/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.6094 - accuracy: 0.6968 - val_loss: 0.6821 - val_accuracy: 0.6786
# Epoch 44/150
# 663/663 [==============================] - 0s 124us/step - loss: 0.5770 - accuracy: 0.7089 - val_loss: 0.5718 - val_accuracy: 0.7857
# Epoch 45/150
# 663/663 [==============================] - 0s 127us/step - loss: 0.5877 - accuracy: 0.7044 - val_loss: 0.6005 - val_accuracy: 0.7857
# Epoch 46/150
# 663/663 [==============================] - 0s 143us/step - loss: 0.5850 - accuracy: 0.6908 - val_loss: 0.5946 - val_accuracy: 0.7500
# Epoch 47/150
# 663/663 [==============================] - 0s 128us/step - loss: 0.6070 - accuracy: 0.6968 - val_loss: 0.5943 - val_accuracy: 0.7143
# Epoch 48/150
# 663/663 [==============================] - 0s 103us/step - loss: 0.5886 - accuracy: 0.7014 - val_loss: 0.6131 - val_accuracy: 0.7500
# Epoch 49/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.5944 - accuracy: 0.6848 - val_loss: 0.6262 - val_accuracy: 0.7500
# Epoch 50/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5913 - accuracy: 0.6863 - val_loss: 0.5724 - val_accuracy: 0.7500
# Epoch 51/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.5623 - accuracy: 0.7134 - val_loss: 0.6120 - val_accuracy: 0.8214
# Epoch 52/150
# 663/663 [==============================] - 0s 109us/step - loss: 0.6141 - accuracy: 0.6938 - val_loss: 0.5892 - val_accuracy: 0.7500
# Epoch 53/150
# 663/663 [==============================] - 0s 109us/step - loss: 0.5593 - accuracy: 0.7179 - val_loss: 0.6270 - val_accuracy: 0.7857
# Epoch 54/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5925 - accuracy: 0.7270 - val_loss: 0.6199 - val_accuracy: 0.7500
# Epoch 55/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.6228 - accuracy: 0.7059 - val_loss: 0.5640 - val_accuracy: 0.7857
# Epoch 56/150
# 663/663 [==============================] - 0s 107us/step - loss: 0.5682 - accuracy: 0.7285 - val_loss: 0.5809 - val_accuracy: 0.7857
# Epoch 57/150
# 663/663 [==============================] - 0s 122us/step - loss: 0.5668 - accuracy: 0.7074 - val_loss: 0.5212 - val_accuracy: 0.7857
# Epoch 58/150
# 663/663 [==============================] - 0s 111us/step - loss: 0.6933 - accuracy: 0.7029 - val_loss: 0.5378 - val_accuracy: 0.7500
# Epoch 59/150
# 663/663 [==============================] - 0s 122us/step - loss: 0.5786 - accuracy: 0.6953 - val_loss: 0.5794 - val_accuracy: 0.7500
# Epoch 60/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5856 - accuracy: 0.7179 - val_loss: 0.7524 - val_accuracy: 0.7143
# Epoch 61/150
# 663/663 [==============================] - 0s 118us/step - loss: 0.5837 - accuracy: 0.7210 - val_loss: 0.5387 - val_accuracy: 0.7857
# Epoch 62/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.5664 - accuracy: 0.7119 - val_loss: 0.5516 - val_accuracy: 0.7143
# Epoch 63/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.5528 - accuracy: 0.7270 - val_loss: 0.7243 - val_accuracy: 0.7500
# Epoch 64/150
# 663/663 [==============================] - 0s 125us/step - loss: 0.5573 - accuracy: 0.7315 - val_loss: 0.5840 - val_accuracy: 0.7857
# Epoch 65/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.5648 - accuracy: 0.7240 - val_loss: 0.5654 - val_accuracy: 0.7857
# Epoch 66/150
# 663/663 [==============================] - 0s 144us/step - loss: 0.5839 - accuracy: 0.7315 - val_loss: 0.5112 - val_accuracy: 0.7857
# Epoch 67/150
# 663/663 [==============================] - 0s 138us/step - loss: 0.5443 - accuracy: 0.7149 - val_loss: 0.5518 - val_accuracy: 0.8214
# Epoch 68/150
# 663/663 [==============================] - 0s 146us/step - loss: 0.5704 - accuracy: 0.7225 - val_loss: 0.5934 - val_accuracy: 0.7500
# Epoch 69/150
# 663/663 [==============================] - 0s 150us/step - loss: 0.5764 - accuracy: 0.7225 - val_loss: 0.5607 - val_accuracy: 0.7500
# Epoch 70/150
# 663/663 [==============================] - 0s 125us/step - loss: 0.5827 - accuracy: 0.7210 - val_loss: 0.6717 - val_accuracy: 0.7143
# Epoch 71/150
# 663/663 [==============================] - 0s 103us/step - loss: 0.5565 - accuracy: 0.7195 - val_loss: 0.5554 - val_accuracy: 0.6786
# Epoch 72/150
# 663/663 [==============================] - 0s 107us/step - loss: 0.5376 - accuracy: 0.7360 - val_loss: 0.5443 - val_accuracy: 0.7143
# Epoch 73/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5465 - accuracy: 0.7315 - val_loss: 0.5453 - val_accuracy: 0.7500
# Epoch 74/150
# 663/663 [==============================] - 0s 101us/step - loss: 0.5397 - accuracy: 0.7451 - val_loss: 0.5696 - val_accuracy: 0.7143
# Epoch 75/150
# 663/663 [==============================] - 0s 99us/step - loss: 0.5367 - accuracy: 0.7360 - val_loss: 0.5484 - val_accuracy: 0.7143
# Epoch 76/150
# 663/663 [==============================] - 0s 97us/step - loss: 0.5483 - accuracy: 0.6998 - val_loss: 0.7110 - val_accuracy: 0.6429
# Epoch 77/150
# 663/663 [==============================] - 0s 98us/step - loss: 0.5637 - accuracy: 0.7149 - val_loss: 0.5475 - val_accuracy: 0.7500
# Epoch 78/150
# 663/663 [==============================] - 0s 107us/step - loss: 0.5368 - accuracy: 0.7526 - val_loss: 0.5414 - val_accuracy: 0.6786
# Epoch 79/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.5665 - accuracy: 0.7089 - val_loss: 0.5186 - val_accuracy: 0.6786
# Epoch 80/150
# 663/663 [==============================] - 0s 133us/step - loss: 0.5545 - accuracy: 0.7255 - val_loss: 0.5565 - val_accuracy: 0.7143
# Epoch 81/150
# 663/663 [==============================] - 0s 146us/step - loss: 0.5298 - accuracy: 0.7526 - val_loss: 0.5755 - val_accuracy: 0.7500
# Epoch 82/150
# 663/663 [==============================] - 0s 145us/step - loss: 0.5337 - accuracy: 0.7330 - val_loss: 0.5494 - val_accuracy: 0.7143
# Epoch 83/150
# 663/663 [==============================] - 0s 148us/step - loss: 0.5336 - accuracy: 0.7330 - val_loss: 0.5732 - val_accuracy: 0.7143
# Epoch 84/150
# 663/663 [==============================] - 0s 118us/step - loss: 0.5383 - accuracy: 0.7240 - val_loss: 0.6193 - val_accuracy: 0.7500
# Epoch 85/150
# 663/663 [==============================] - 0s 111us/step - loss: 0.7967 - accuracy: 0.6682 - val_loss: 0.5725 - val_accuracy: 0.7857
# Epoch 86/150
# 663/663 [==============================] - 0s 140us/step - loss: 0.5601 - accuracy: 0.7315 - val_loss: 0.5167 - val_accuracy: 0.6786
# Epoch 87/150
# 663/663 [==============================] - 0s 137us/step - loss: 0.5152 - accuracy: 0.7391 - val_loss: 0.5004 - val_accuracy: 0.7500
# Epoch 88/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5436 - accuracy: 0.7572 - val_loss: 0.5354 - val_accuracy: 0.7143
# Epoch 89/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5360 - accuracy: 0.7270 - val_loss: 0.6042 - val_accuracy: 0.7500
# Epoch 90/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.5572 - accuracy: 0.7300 - val_loss: 0.5085 - val_accuracy: 0.8214
# Epoch 91/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.5595 - accuracy: 0.7391 - val_loss: 0.6123 - val_accuracy: 0.7143
# Epoch 92/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5404 - accuracy: 0.7345 - val_loss: 0.5457 - val_accuracy: 0.7500
# Epoch 93/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.5194 - accuracy: 0.7496 - val_loss: 0.4774 - val_accuracy: 0.6786
# Epoch 94/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5439 - accuracy: 0.7406 - val_loss: 0.5343 - val_accuracy: 0.7143
# Epoch 95/150
# 663/663 [==============================] - 0s 125us/step - loss: 0.5105 - accuracy: 0.7391 - val_loss: 0.6932 - val_accuracy: 0.6786
# Epoch 96/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5692 - accuracy: 0.7270 - val_loss: 0.5089 - val_accuracy: 0.7143
# Epoch 97/150
# 663/663 [==============================] - 0s 110us/step - loss: 0.5543 - accuracy: 0.7330 - val_loss: 0.5477 - val_accuracy: 0.7143
# Epoch 98/150
# 663/663 [==============================] - 0s 102us/step - loss: 0.5147 - accuracy: 0.7421 - val_loss: 0.4928 - val_accuracy: 0.6786
# Epoch 99/150
# 663/663 [==============================] - 0s 103us/step - loss: 0.5298 - accuracy: 0.7315 - val_loss: 0.4905 - val_accuracy: 0.7143
# Epoch 100/150
# 663/663 [==============================] - 0s 108us/step - loss: 0.5401 - accuracy: 0.7345 - val_loss: 0.5052 - val_accuracy: 0.6786
# Epoch 101/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5415 - accuracy: 0.7436 - val_loss: 0.5519 - val_accuracy: 0.7143
# Epoch 102/150
# 663/663 [==============================] - 0s 117us/step - loss: 0.5373 - accuracy: 0.7436 - val_loss: 0.5632 - val_accuracy: 0.7143
# Epoch 103/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5093 - accuracy: 0.7511 - val_loss: 0.6237 - val_accuracy: 0.7143
# Epoch 104/150
# 663/663 [==============================] - 0s 120us/step - loss: 0.5249 - accuracy: 0.7345 - val_loss: 0.4963 - val_accuracy: 0.7857
# Epoch 105/150
# 663/663 [==============================] - 0s 114us/step - loss: 0.5473 - accuracy: 0.7391 - val_loss: 0.5007 - val_accuracy: 0.7143
# Epoch 106/150
# 663/663 [==============================] - 0s 114us/step - loss: 0.5399 - accuracy: 0.7406 - val_loss: 0.5193 - val_accuracy: 0.7857
# Epoch 107/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5269 - accuracy: 0.7330 - val_loss: 0.5198 - val_accuracy: 0.6786
# Epoch 108/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5198 - accuracy: 0.7360 - val_loss: 0.5000 - val_accuracy: 0.7857
# Epoch 109/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.5068 - accuracy: 0.7376 - val_loss: 0.5325 - val_accuracy: 0.7857
# Epoch 110/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5283 - accuracy: 0.7496 - val_loss: 0.5523 - val_accuracy: 0.7143
# Epoch 111/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5050 - accuracy: 0.7647 - val_loss: 0.5259 - val_accuracy: 0.7500
# Epoch 112/150
# 663/663 [==============================] - 0s 144us/step - loss: 0.5228 - accuracy: 0.7617 - val_loss: 0.5722 - val_accuracy: 0.7857
# Epoch 113/150
# 663/663 [==============================] - 0s 101us/step - loss: 0.5309 - accuracy: 0.7270 - val_loss: 0.5096 - val_accuracy: 0.7143
# Epoch 114/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5458 - accuracy: 0.7451 - val_loss: 0.6610 - val_accuracy: 0.6786
# Epoch 115/150
# 663/663 [==============================] - 0s 96us/step - loss: 0.5596 - accuracy: 0.7315 - val_loss: 0.5316 - val_accuracy: 0.7857
# Epoch 116/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5035 - accuracy: 0.7511 - val_loss: 0.5264 - val_accuracy: 0.7500
# Epoch 117/150
# 663/663 [==============================] - 0s 121us/step - loss: 0.5231 - accuracy: 0.7406 - val_loss: 0.6060 - val_accuracy: 0.7500
# Epoch 118/150
# 663/663 [==============================] - 0s 115us/step - loss: 0.5358 - accuracy: 0.7526 - val_loss: 0.4864 - val_accuracy: 0.7857
# Epoch 119/150
# 663/663 [==============================] - 0s 118us/step - loss: 0.5141 - accuracy: 0.7541 - val_loss: 0.5088 - val_accuracy: 0.7500
# Epoch 120/150
# 663/663 [==============================] - 0s 119us/step - loss: 0.5205 - accuracy: 0.7511 - val_loss: 0.4752 - val_accuracy: 0.7857
# Epoch 121/150
# 663/663 [==============================] - 0s 123us/step - loss: 0.5146 - accuracy: 0.7662 - val_loss: 0.5030 - val_accuracy: 0.8214
# Epoch 122/150
# 663/663 [==============================] - 0s 114us/step - loss: 0.5007 - accuracy: 0.7526 - val_loss: 0.5190 - val_accuracy: 0.7500
# Epoch 123/150
# 663/663 [==============================] - 0s 116us/step - loss: 0.5165 - accuracy: 0.7511 - val_loss: 0.4931 - val_accuracy: 0.7857
# Epoch 124/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5312 - accuracy: 0.7451 - val_loss: 0.5309 - val_accuracy: 0.7143
# Epoch 125/150
# 663/663 [==============================] - 0s 145us/step - loss: 0.5001 - accuracy: 0.7632 - val_loss: 0.4413 - val_accuracy: 0.7857
# Epoch 126/150
# 663/663 [==============================] - 0s 124us/step - loss: 0.4907 - accuracy: 0.7738 - val_loss: 0.4983 - val_accuracy: 0.7143
# Epoch 127/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.5057 - accuracy: 0.7526 - val_loss: 0.4965 - val_accuracy: 0.7500
# Epoch 128/150
# 663/663 [==============================] - 0s 102us/step - loss: 0.5232 - accuracy: 0.7617 - val_loss: 0.4556 - val_accuracy: 0.8214
# Epoch 129/150
# 663/663 [==============================] - 0s 103us/step - loss: 0.4875 - accuracy: 0.7602 - val_loss: 0.4739 - val_accuracy: 0.7857
# Epoch 130/150
# 663/663 [==============================] - 0s 100us/step - loss: 0.4979 - accuracy: 0.7526 - val_loss: 0.4482 - val_accuracy: 0.7857
# Epoch 131/150
# 663/663 [==============================] - 0s 127us/step - loss: 0.4975 - accuracy: 0.7647 - val_loss: 0.4954 - val_accuracy: 0.7143
# Epoch 132/150
# 663/663 [==============================] - 0s 106us/step - loss: 0.4989 - accuracy: 0.7617 - val_loss: 0.4716 - val_accuracy: 0.7500
# Epoch 133/150
# 663/663 [==============================] - 0s 104us/step - loss: 0.5285 - accuracy: 0.7466 - val_loss: 0.5450 - val_accuracy: 0.7857
# Epoch 134/150
# 663/663 [==============================] - 0s 107us/step - loss: 0.5001 - accuracy: 0.7692 - val_loss: 0.4917 - val_accuracy: 0.7500
# Epoch 135/150
# 663/663 [==============================] - 0s 123us/step - loss: 0.5345 - accuracy: 0.7526 - val_loss: 0.5637 - val_accuracy: 0.6786
# Epoch 136/150
# 663/663 [==============================] - 0s 109us/step - loss: 0.5180 - accuracy: 0.7526 - val_loss: 0.5498 - val_accuracy: 0.6786
# Epoch 137/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.5195 - accuracy: 0.7466 - val_loss: 0.5060 - val_accuracy: 0.6786
# Epoch 138/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.5268 - accuracy: 0.7496 - val_loss: 0.5064 - val_accuracy: 0.7143
# Epoch 139/150
# 663/663 [==============================] - 0s 113us/step - loss: 0.4999 - accuracy: 0.7738 - val_loss: 0.4651 - val_accuracy: 0.6786
# Epoch 140/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4994 - accuracy: 0.7602 - val_loss: 0.5201 - val_accuracy: 0.7143
# Epoch 141/150
# 663/663 [==============================] - 0s 114us/step - loss: 0.5221 - accuracy: 0.7632 - val_loss: 0.5276 - val_accuracy: 0.7143
# Epoch 142/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4797 - accuracy: 0.7813 - val_loss: 0.5560 - val_accuracy: 0.8214
# Epoch 143/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5247 - accuracy: 0.7526 - val_loss: 0.4796 - val_accuracy: 0.8214
# Epoch 144/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4972 - accuracy: 0.7526 - val_loss: 0.4682 - val_accuracy: 0.7857
# Epoch 145/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4833 - accuracy: 0.7722 - val_loss: 0.5079 - val_accuracy: 0.7500
# Epoch 146/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.5072 - accuracy: 0.7451 - val_loss: 0.4452 - val_accuracy: 0.8214
# Epoch 147/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4885 - accuracy: 0.7647 - val_loss: 0.4823 - val_accuracy: 0.8214
# Epoch 148/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4931 - accuracy: 0.7722 - val_loss: 0.4627 - val_accuracy: 0.7857
# Epoch 149/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4957 - accuracy: 0.7587 - val_loss: 0.5223 - val_accuracy: 0.7500
# Epoch 150/150
# 663/663 [==============================] - 0s 112us/step - loss: 0.4986 - accuracy: 0.7602 - val_loss: 0.5281 - val_accuracy: 0.8214
#
# history dict: {'val_loss': [11.163568360464913, 4.366541368620736, 1.9985964468547277, 1.7966578687940324, 1.4875566533633642, 1.3419804317610604, 1.2150044015475683, 1.086950523512704, 1.1440920787198203, 0.9690499603748322, 0.985221232686724, 1.0929056320871626, 0.8620911283152444, 0.8196115110601697, 0.7871137261390686, 0.9438997549670083, 0.7692305275372097, 0.895451273236956, 0.7011261454650334, 0.6817699074745178, 0.7097360640764236, 0.6599361641066415, 0.7006687011037555, 0.6545883800302233, 0.659463712147304, 0.6579398683139256, 0.6490890383720398, 0.6438664793968201, 0.6360116515840802, 0.6332382261753082, 0.6129136660269329, 0.6561729311943054, 0.6755418522017342, 0.6124753952026367, 0.6057558464152473, 0.6030067375728062, 0.6032840268952506, 0.6213486726794925, 0.6004805394581386, 0.6160819189889091, 0.621585875749588, 0.5850827395915985, 0.6820862335818154, 0.5717658613409314, 0.6004631412880761, 0.5945960198129926, 0.5943073758057186, 0.6130713522434235, 0.6262018510273525, 0.5723984177623477, 0.6120150557586125, 0.5892189762422017, 0.6269575251000268, 0.6199495366641453, 0.5640124401875904, 0.5808543051992144, 0.5212246392454419, 0.5378355256148747, 0.5793839671782085, 0.752443036862782, 0.5386696308851242, 0.5515810038362231, 0.7243461310863495, 0.584026174885886, 0.5654209213597434, 0.5112268030643463, 0.5517565778323582, 0.5934033159698758, 0.5606686132294791, 0.6716515677315849, 0.5553951646600451, 0.5443039408751896, 0.5452988083873477, 0.5696059507983071, 0.5484394643987928, 0.7109842939036233, 0.5475061471973147, 0.5413819828203746, 0.5186493737357003, 0.5565237296479089, 0.5754632183483669, 0.5494368374347687, 0.5731672602040427, 0.6192673657621656, 0.572457070861544, 0.5166826546192169, 0.5003681182861328, 0.5353813064949853, 0.6042054146528244, 0.5085444471665791, 0.6123487268175397, 0.5456582712275642, 0.4773671350308827, 0.5342604879822049, 0.6932032789502826, 0.5089072287082672, 0.5476550779172352, 0.49284295099122183, 0.4904795948948179, 0.505174287727901, 0.5518613308668137, 0.5631551210369382, 0.6236925636019025, 0.4963424780539104, 0.5006602938686099, 0.5192847039018359, 0.5197933869702476, 0.5000041446515492, 0.5324659943580627, 0.5522891495909009, 0.5258554688521794, 0.5722006836107799, 0.509580346090453, 0.6609688954693931, 0.5315812400409153, 0.5264203931604113, 0.6059680495943341, 0.48644843484674183, 0.5087878086737224, 0.4751800724438259, 0.5029520626579013, 0.5190088344471795, 0.49312180493559155, 0.530869864991733, 0.44129153873239246, 0.4982754502977644, 0.4964844754764012, 0.4555822248969759, 0.4738587439060211, 0.4481784062726157, 0.4954304652554648, 0.4715801051684788, 0.5449797127928052, 0.49165249935218264, 0.5636991219861167, 0.5497731672866004, 0.506043057356562, 0.5063914763075965, 0.4651388568537576, 0.5200540274381638, 0.527597616825785, 0.5560022656406675, 0.4795802022729601, 0.4682213749204363, 0.5078551854406085, 0.4451694233076913, 0.4822806694677898, 0.4627308653933661, 0.5222553483077458, 0.5280522533825466], 'val_accuracy': [0.7142857313156128, 0.6071428656578064, 0.6071428656578064, 0.4285714328289032, 0.5357142686843872, 0.5, 0.5, 0.5714285969734192, 0.5357142686843872, 0.5357142686843872, 0.5714285969734192, 0.5357142686843872, 0.6071428656578064, 0.5357142686843872, 0.5357142686843872, 0.4642857015132904, 0.6428571343421936, 0.5714285969734192, 0.6071428656578064, 0.6071428656578064, 0.5714285969734192, 0.6785714030265808, 0.5714285969734192, 0.5714285969734192, 0.6071428656578064, 0.6785714030265808, 0.6785714030265808, 0.7142857313156128, 0.6428571343421936, 0.7142857313156128, 0.75, 0.6428571343421936, 0.6428571343421936, 0.7142857313156128, 0.7142857313156128, 0.8571428656578064, 0.7857142686843872, 0.6785714030265808, 0.7142857313156128, 0.7857142686843872, 0.6785714030265808, 0.8571428656578064, 0.6785714030265808, 0.7857142686843872, 0.7857142686843872, 0.75, 0.7142857313156128, 0.75, 0.75, 0.75, 0.8214285969734192, 0.75, 0.7857142686843872, 0.75, 0.785714268 ...

# %% [markdown]
# #### Evaluate

# %%
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, Y_test)
print('test loss, test acc:', results)
# Out:
# # Evaluate on test data
# 77/77 [==============================] - 0s 56us/step
# test loss, test acc: [0.5486548550717243, 0.7142857313156128]

# %% [markdown]
# #### Predictions
#
# The number one question I get asked is:
#
# > After I train my model, how can I use it to make predictions on new data?
#
# this is a great question.

# %%
# make probability predictions with the model
new_patient = np.array([4.00e+00, 1.48e+02, 6.00e+01, 2.70e+01, 3.18e+02, 3.09e+01,
       1.50e-01, 2.90e+01]).reshape(1,-1)

prob_pred = model.predict(new_patient)

prediction = round(float(prob_pred[[0]]))

# %% [markdown]
# ## Back to cats

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %%
# Explore your dataset 
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(train_x_orig.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x_orig shape: " + str(test_x_orig.shape))
print ("test_y shape: " + str(test_y.shape))
# Out:
# Number of training examples: 209
# Number of testing examples: 50
# Each image is of size: (64, 64, 3)
# train_x_orig shape: (209, 64, 64, 3)
# train_y shape: (1, 209)
# test_x_orig shape: (50, 64, 64, 3)
# test_y shape: (1, 50)

# %% [markdown]
# As usual, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# <img src="images/imvectorkiank.png" style="width:450px;height:300px;">
#
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# Standardize data to have feature values between 0 and 1.
train_x = (train_x_flatten/255.)
test_x = (test_x_flatten/255.)

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)

# %% [markdown]
# $12,288$ equals $64 \times 64 \times 3$ which is the size of one reshaped image vector.

# %% [markdown]
# ## The model

# %% [markdown]
# Now that you are familiar with the dataset, it is time to build a deep neural network to distinguish cat images from non-cat images.
#
# You will build two different models:
# - A 2-layer neural network
# - An L-layer deep neural network
#
# You will then compare the performance of these models, and also try out different values for $L$.
#
# Let's look at the two architectures.
#
# ### 2-layer neural network
#
# <img src="images/2layerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 2</u>: 2-layer neural network. <br> The model can be summarized as: ***INPUT -> LINEAR -> RELU -> LINEAR -> SIGMOID -> OUTPUT***. </center></caption>
#
# <u>Detailed Architecture of figure 2</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size $(12288,1)$.
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ of size $(n^{[1]}, 12288)$.
# - You then add a bias term and take its relu to get the following vector: $[a_0^{[1]}, a_1^{[1]},..., a_{n^{[1]}-1}^{[1]}]^T$.
# - You then repeat the same process.
# - You multiply the resulting vector by $W^{[2]}$ and add your intercept (bias).
# - Finally, you take the sigmoid of the result. If it is greater than 0.5, you classify it to be a cat.
#
# ###  L-layer deep neural network
#
# It is hard to represent an L-layer deep neural network with the above representation. However, here is a simplified network representation:
#
# <img src="images/LlayerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 3</u>: L-layer neural network. <br> The model can be summarized as: ***[LINEAR -> RELU] $\times$ (L-1) -> LINEAR -> SIGMOID***</center></caption>
#
# <u>Detailed Architecture of figure 3</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size (12288,1).
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ and then you add the intercept $b^{[1]}$. The result is called the linear unit.
# - Next, you take the relu of the linear unit. This process could be repeated several times for each $(W^{[l]}, b^{[l]})$ depending on the model architecture.
# - Finally, you take the sigmoid of the final linear unit. If it is greater than 0.5, you classify it to be a cat.
#
# ### 3.3 - General methodology
#
# As usual you will follow the Keras/Deep Learning methodology to build the model:
#     1. Design the shape of your model
#     2. Add layers to your `Sequential model`
#     3. Train the parameters on the training set
#     4. Use learnt parameters to make predictions on new data.
#
# Let's now implement those two models!

# %%
n_x = 12288     # num_px * num_px * 3

# %%
def two_layer_model(n_units_1, n_units_2 = 1):
    """
        function to define a two-layer neural network model.
        
        Parameters:
        ----------
            - n_units_1 : int
                            number of hidden units of the first hidden layer.
                            
            - n_units_2 : int
                            number of hidden units of the second hidden layer.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units_1, input_dim=n_x, activation = 'tanh', kernel_initializer='uniform', name = 'first_hidden_layer'))
    model.add(Dense(n_units_2, activation = 'sigmoid', name = 'output_layer'))
    
    return model

# %%
model = two_layer_model(7)

# %%
opt = optimizers.Adam(lr = 1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# first_hidden_layer (Dense)   (None, 7)                 86023
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 8
# =================================================================
# Total params: 86,031
# Trainable params: 86,031
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_y = train_y.T

# %%
model.fit(train_x, train_y, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.6701 - accuracy: 0.6316
# Epoch 2/100
# 209/209 [==============================] - 0s 216us/step - loss: 0.6618 - accuracy: 0.6411
# Epoch 3/100
# 209/209 [==============================] - 0s 214us/step - loss: 0.6565 - accuracy: 0.6411
# Epoch 4/100
# 209/209 [==============================] - 0s 362us/step - loss: 0.6515 - accuracy: 0.6459
# Epoch 5/100
# 209/209 [==============================] - 0s 235us/step - loss: 0.6448 - accuracy: 0.6459
# Epoch 6/100
# 209/209 [==============================] - 0s 280us/step - loss: 0.6416 - accuracy: 0.6507
# Epoch 7/100
# 209/209 [==============================] - 0s 224us/step - loss: 0.6365 - accuracy: 0.6507
# Epoch 8/100
# 209/209 [==============================] - 0s 239us/step - loss: 0.6331 - accuracy: 0.6555
# Epoch 9/100
# 209/209 [==============================] - 0s 249us/step - loss: 0.6299 - accuracy: 0.6555
# Epoch 10/100
# 209/209 [==============================] - 0s 261us/step - loss: 0.6263 - accuracy: 0.6507
# Epoch 11/100
# 209/209 [==============================] - 0s 277us/step - loss: 0.6233 - accuracy: 0.6603
# Epoch 12/100
# 209/209 [==============================] - 0s 264us/step - loss: 0.6197 - accuracy: 0.6699
# Epoch 13/100
# 209/209 [==============================] - 0s 248us/step - loss: 0.6174 - accuracy: 0.6651
# Epoch 14/100
# 209/209 [==============================] - 0s 206us/step - loss: 0.6172 - accuracy: 0.6699
# Epoch 15/100
# 209/209 [==============================] - 0s 210us/step - loss: 0.6087 - accuracy: 0.6699
# Epoch 16/100
# 209/209 [==============================] - 0s 205us/step - loss: 0.6066 - accuracy: 0.6699
# Epoch 17/100
# 209/209 [==============================] - 0s 193us/step - loss: 0.6036 - accuracy: 0.6746
# Epoch 18/100
# 209/209 [==============================] - 0s 194us/step - loss: 0.5997 - accuracy: 0.6794
# Epoch 19/100
# 209/209 [==============================] - 0s 190us/step - loss: 0.5976 - accuracy: 0.6842
# Epoch 20/100
# 209/209 [==============================] - 0s 193us/step - loss: 0.5950 - accuracy: 0.6842
# Epoch 21/100
# 209/209 [==============================] - 0s 194us/step - loss: 0.5896 - accuracy: 0.6938
# Epoch 22/100
# 209/209 [==============================] - 0s 198us/step - loss: 0.5858 - accuracy: 0.6938
# Epoch 23/100
# 209/209 [==============================] - 0s 199us/step - loss: 0.5852 - accuracy: 0.6890
# Epoch 24/100
# 209/209 [==============================] - 0s 197us/step - loss: 0.5786 - accuracy: 0.6938
# Epoch 25/100
# 209/209 [==============================] - 0s 198us/step - loss: 0.5760 - accuracy: 0.6986
# Epoch 26/100
# 209/209 [==============================] - 0s 197us/step - loss: 0.5747 - accuracy: 0.6938
# Epoch 27/100
# 209/209 [==============================] - 0s 210us/step - loss: 0.5742 - accuracy: 0.6794
# Epoch 28/100
# 209/209 [==============================] - 0s 330us/step - loss: 0.5671 - accuracy: 0.7081
# Epoch 29/100
# 209/209 [==============================] - 0s 208us/step - loss: 0.5626 - accuracy: 0.7081
# Epoch 30/100
# 209/209 [==============================] - 0s 196us/step - loss: 0.5586 - accuracy: 0.7225
# Epoch 31/100
# 209/209 [==============================] - 0s 215us/step - loss: 0.5571 - accuracy: 0.7177
# Epoch 32/100
# 209/209 [==============================] - 0s 213us/step - loss: 0.5567 - accuracy: 0.7177
# Epoch 33/100
# 209/209 [==============================] - 0s 225us/step - loss: 0.5500 - accuracy: 0.7225
# Epoch 34/100
# 209/209 [==============================] - 0s 212us/step - loss: 0.5474 - accuracy: 0.7177
# Epoch 35/100
# 209/209 [==============================] - 0s 265us/step - loss: 0.5438 - accuracy: 0.7368
# Epoch 36/100
# 209/209 [==============================] - 0s 247us/step - loss: 0.5426 - accuracy: 0.7368
# Epoch 37/100
# 209/209 [==============================] - 0s 265us/step - loss: 0.5400 - accuracy: 0.7368
# Epoch 38/100
# 209/209 [==============================] - 0s 225us/step - loss: 0.5366 - accuracy: 0.7416
# Epoch 39/100
# 209/209 [==============================] - 0s 213us/step - loss: 0.5371 - accuracy: 0.7416
# Epoch 40/100
# 209/209 [==============================] - 0s 244us/step - loss: 0.5315 - accuracy: 0.7416
# Epoch 41/100
# 209/209 [==============================] - 0s 238us/step - loss: 0.5297 - accuracy: 0.7416
# Epoch 42/100
# 209/209 [==============================] - 0s 264us/step - loss: 0.5276 - accuracy: 0.7464
# Epoch 43/100
# 209/209 [==============================] - 0s 221us/step - loss: 0.5260 - accuracy: 0.7464
# Epoch 44/100
# 209/209 [==============================] - 0s 218us/step - loss: 0.5244 - accuracy: 0.7464
# Epoch 45/100
# 209/209 [==============================] - 0s 349us/step - loss: 0.5238 - accuracy: 0.7368
# Epoch 46/100
# 209/209 [==============================] - 0s 214us/step - loss: 0.5205 - accuracy: 0.7464
# Epoch 47/100
# 209/209 [==============================] - 0s 228us/step - loss: 0.5182 - accuracy: 0.7416
# Epoch 48/100
# 209/209 [==============================] - 0s 301us/step - loss: 0.5172 - accuracy: 0.7464
# Epoch 49/100
# 209/209 [==============================] - 0s 260us/step - loss: 0.5145 - accuracy: 0.7656
# Epoch 50/100
# 209/209 [==============================] - 0s 234us/step - loss: 0.5125 - accuracy: 0.7656
# Epoch 51/100
# 209/209 [==============================] - 0s 250us/step - loss: 0.5108 - accuracy: 0.7656
# Epoch 52/100
# 209/209 [==============================] - 0s 243us/step - loss: 0.5089 - accuracy: 0.7560
# Epoch 53/100
# 209/209 [==============================] - 0s 281us/step - loss: 0.5078 - accuracy: 0.7656
# Epoch 54/100
# 209/209 [==============================] - 0s 247us/step - loss: 0.5052 - accuracy: 0.7799
# Epoch 55/100
# 209/209 [==============================] - 0s 280us/step - loss: 0.5069 - accuracy: 0.7895
# Epoch 56/100
# 209/209 [==============================] - 0s 283us/step - loss: 0.5021 - accuracy: 0.7703
# Epoch 57/100
# 209/209 [==============================] - 0s 226us/step - loss: 0.5022 - accuracy: 0.7799
# Epoch 58/100
# 209/209 [==============================] - 0s 246us/step - loss: 0.4976 - accuracy: 0.7656
# Epoch 59/100
# 209/209 [==============================] - 0s 228us/step - loss: 0.4964 - accuracy: 0.7751
# Epoch 60/100
# 209/209 [==============================] - 0s 276us/step - loss: 0.4951 - accuracy: 0.7799
# Epoch 61/100
# 209/209 [==============================] - 0s 232us/step - loss: 0.4934 - accuracy: 0.7990
# Epoch 62/100
# 209/209 [==============================] - 0s 222us/step - loss: 0.4914 - accuracy: 0.7895
# Epoch 63/100
# 209/209 [==============================] - 0s 237us/step - loss: 0.4911 - accuracy: 0.7895
# Epoch 64/100
# 209/209 [==============================] - 0s 238us/step - loss: 0.4889 - accuracy: 0.7895
# Epoch 65/100
# 209/209 [==============================] - 0s 228us/step - loss: 0.4868 - accuracy: 0.7943
# Epoch 66/100
# 209/209 [==============================] - 0s 223us/step - loss: 0.4867 - accuracy: 0.8086
# Epoch 67/100
# 209/209 [==============================] - 0s 240us/step - loss: 0.4885 - accuracy: 0.7895
# Epoch 68/100
# 209/209 [==============================] - 0s 227us/step - loss: 0.4840 - accuracy: 0.7895
# Epoch 69/100
# 209/209 [==============================] - 0s 269us/step - loss: 0.4844 - accuracy: 0.8086
# Epoch 70/100
# 209/209 [==============================] - 0s 231us/step - loss: 0.4790 - accuracy: 0.8134
# Epoch 71/100
# 209/209 [==============================] - 0s 264us/step - loss: 0.4833 - accuracy: 0.7703
# Epoch 72/100
# 209/209 [==============================] - 0s 238us/step - loss: 0.4780 - accuracy: 0.8086
# Epoch 73/100
# 209/209 [==============================] - 0s 261us/step - loss: 0.4777 - accuracy: 0.8086
# Epoch 74/100
# 209/209 [==============================] - 0s 235us/step - loss: 0.4774 - accuracy: 0.7943
# Epoch 75/100
# 209/209 [==============================] - 0s 258us/step - loss: 0.4711 - accuracy: 0.8038
# Epoch 76/100
# 209/209 [==============================] - 0s 220us/step - loss: 0.4734 - accuracy: 0.8134
# Epoch 77/100
# 209/209 [==============================] - 0s 217us/step - loss: 0.4723 - accuracy: 0.8086
# Epoch 78/100
# 209/209 [==============================] - 0s 207us/step - loss: 0.4703 - accuracy: 0.8134
# Epoch 79/100
# 209/209 [==============================] - 0s 215us/step - loss: 0.4708 - accuracy: 0.8182
# Epoch 80/100
# 209/209 [==============================] - 0s 196us/step - loss: 0.4685 - accuracy: 0.8086
# Epoch 81/100
# 209/209 [==============================] - 0s 207us/step - loss: 0.4662 - accuracy: 0.8134
# Epoch 82/100
# 209/209 [==============================] - 0s 275us/step - loss: 0.4657 - accuracy: 0.8134
# Epoch 83/100
# 209/209 [==============================] - 0s 582us/step - loss: 0.4641 - accuracy: 0.8134
# Epoch 84/100
# 209/209 [==============================] - 0s 231us/step - loss: 0.4634 - accuracy: 0.8230
# Epoch 85/100
# 209/209 [==============================] - 0s 215us/step - loss: 0.4616 - accuracy: 0.8182
# Epoch 86/100
# 209/209 [==============================] - 0s 197us/step - loss: 0.4592 - accuracy: 0.8086
# Epoch 87/100
# 209/209 [==============================] - 0s 188us/step - loss: 0.4589 - accuracy: 0.8134
# Epoch 88/100
# 209/209 [==============================] - 0s 200us/step - loss: 0.4589 - accuracy: 0.8230
# Epoch 89/100
# 209/209 [==============================] - 0s 195us/step - loss: 0.4563 - accuracy: 0.8182
# Epoch 90/100
# 209/209 [==============================] - 0s 192us/step - loss: 0.4553 - accuracy: 0.8230
# Epoch 91/100
# 209/209 [==============================] - 0s 230us/step - loss: 0.4543 - accuracy: 0.8230
# Epoch 92/100
# 209/209 [==============================] - 0s 215us/step - loss: 0.4534 - accuracy: 0.8230
# Epoch 93/100
# 209/209 [==============================] - 0s 230us/step - loss: 0.4522 - accuracy: 0.8230
# Epoch 94/100
# 209/209 [==============================] - 0s 212us/step - loss: 0.4513 - accuracy: 0.8134
# Epoch 95/100
# 209/209 [==============================] - 0s 212us/step - loss: 0.4523 - accuracy: 0.8230
# Epoch 96/100
# 209/209 [==============================] - 0s 214us/step - loss: 0.4481 - accuracy: 0.8230
# Epoch 97/100
# 209/209 [==============================] - 0s 207us/step - loss: 0.4480 - accuracy: 0.8325
# Epoch 98/100
# 209/209 [==============================] - 0s 205us/step - loss: 0.4478 - accuracy: 0.8278
# Epoch 99/100
# 209/209 [==============================] - 0s 213us/step - loss: 0.4490 - accuracy: 0.8182
# Epoch 100/100
# 209/209 [==============================] - 0s 230us/step - loss: 0.4446 - accuracy: 0.8325

# %%
# Predictions on test set
model.predict(test_x)
# Out:
# array([[0.5595838 ],
#        [0.6768249 ],
#        [0.59774154],
#        [0.47926992],
#        [0.40611807],
#        [0.6409394 ],
#        [0.25801557],
#        [0.5276974 ],
#        [0.62381625],
#        [0.6662719 ],
#        [0.37921557],
#        [0.57445425],
#        [0.5881113 ],
#        [0.4641428 ],
#        [0.25770164],
#        [0.6888804 ],
#        [0.1893684 ],
#        [0.4039139 ],
#        [0.16959578],
#        [0.15062115],
#        [0.5451358 ],
#        [0.11848444],
#        [0.20122668],
#        [0.4116546 ],
#        [0.70343757],
#        [0.6675508 ],
#        [0.28593355],
#        [0.32450822],
#        [0.32931972],
#        [0.6874685 ],
#        [0.37174284],
#        [0.63421905],
#        [0.30683947],
#        [0.30186865],
#        [0.44332927],
#        [0.18948147],
#        [0.27447757],
#        [0.5829918 ],
#        [0.64231336],
#        [0.15291646],
#        [0.39763272],
#        [0.5587817 ],
#        [0.50026435],
#        [0.15227732],
#        [0.77884865],
#        [0.34111863],
#        [0.21917766],
#        [0.717357  ],
#        [0.52816385],
#        [0.32514724]], dtype=float32)

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 50/50 [==============================] - 0s 893us/step
#
# # Evaluate
# {'loss': 0.7102979040145874, 'accuracy': 0.6200000047683716}

# %% [markdown]
# ### L-layer model

# %%
def L_layer_model(n_layers, n_units, n_x):
    """
        function to define an L-layer neural network model.
        
        Parameters:
        ----------
            - n_layers : int
                            number of hidden layers + output layer.
                            
            - n_units :  list of int
                            number of hidden units of for each hidden layer.
                            
            - n_x : int
                        number of input features.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units[0], input_dim = n_x, activation = 'relu',  kernel_initializer='uniform')) # first layer
    for l in range(1,n_layers):
        if l == n_layers-1:
            model.add(Dropout(rate=0.5))
            model.add(Dense(n_units[l], activation = 'sigmoid', name = 'output_layer')) # output layer
        else:
            model.add(Dense(n_units[l], activation = 'relu', name = 'hidden_layer_' + str(l)))
        
    return model

# %%
n_layers = 3
n_units = [10, 5, 1]

model = L_layer_model(n_layers, n_units, n_x)

# %%
opt = optimizers.Adam(lr=1e-4)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                122890
# _________________________________________________________________
# hidden_layer_1 (Dense)       (None, 5)                 55
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 6
# =================================================================
# Total params: 122,951
# Trainable params: 122,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_x, train_y, batch_size=32, epochs=150, validation_split=0.2)
# Out:
# Train on 167 samples, validate on 42 samples
# Epoch 1/150
# 167/167 [==============================] - 0s 3ms/step - loss: 0.7229 - accuracy: 0.4910 - val_loss: 0.6822 - val_accuracy: 0.6429
# Epoch 2/150
# 167/167 [==============================] - 0s 172us/step - loss: 0.6828 - accuracy: 0.6407 - val_loss: 0.6583 - val_accuracy: 0.6905
# Epoch 3/150
# 167/167 [==============================] - 0s 242us/step - loss: 0.6806 - accuracy: 0.6287 - val_loss: 0.6509 - val_accuracy: 0.6905
# Epoch 4/150
# 167/167 [==============================] - 0s 213us/step - loss: 0.6700 - accuracy: 0.6407 - val_loss: 0.6508 - val_accuracy: 0.6905
# Epoch 5/150
# 167/167 [==============================] - 0s 200us/step - loss: 0.6700 - accuracy: 0.6467 - val_loss: 0.6483 - val_accuracy: 0.6905
# Epoch 6/150
# 167/167 [==============================] - 0s 212us/step - loss: 0.6875 - accuracy: 0.6467 - val_loss: 0.6563 - val_accuracy: 0.6429
# Epoch 7/150
# 167/167 [==============================] - 0s 199us/step - loss: 0.6661 - accuracy: 0.6407 - val_loss: 0.6553 - val_accuracy: 0.6667
# Epoch 8/150
# 167/167 [==============================] - 0s 199us/step - loss: 0.6577 - accuracy: 0.6467 - val_loss: 0.6438 - val_accuracy: 0.6905
# Epoch 9/150
# 167/167 [==============================] - 0s 251us/step - loss: 0.6709 - accuracy: 0.6407 - val_loss: 0.6357 - val_accuracy: 0.6905
# Epoch 10/150
# 167/167 [==============================] - 0s 183us/step - loss: 0.6911 - accuracy: 0.6407 - val_loss: 0.6351 - val_accuracy: 0.6905
# Epoch 11/150
# 167/167 [==============================] - 0s 184us/step - loss: 0.6614 - accuracy: 0.6407 - val_loss: 0.6384 - val_accuracy: 0.6905
# Epoch 12/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.6931 - accuracy: 0.6467 - val_loss: 0.6458 - val_accuracy: 0.6905
# Epoch 13/150
# 167/167 [==============================] - 0s 245us/step - loss: 0.6556 - accuracy: 0.6467 - val_loss: 0.6483 - val_accuracy: 0.6905
# Epoch 14/150
# 167/167 [==============================] - 0s 222us/step - loss: 0.6634 - accuracy: 0.6527 - val_loss: 0.6471 - val_accuracy: 0.7143
# Epoch 15/150
# 167/167 [==============================] - 0s 172us/step - loss: 0.6652 - accuracy: 0.6467 - val_loss: 0.6483 - val_accuracy: 0.7143
# Epoch 16/150
# 167/167 [==============================] - 0s 255us/step - loss: 0.6721 - accuracy: 0.6707 - val_loss: 0.6532 - val_accuracy: 0.6667
# Epoch 17/150
# 167/167 [==============================] - 0s 211us/step - loss: 0.6785 - accuracy: 0.6527 - val_loss: 0.6621 - val_accuracy: 0.6190
# Epoch 18/150
# 167/167 [==============================] - 0s 226us/step - loss: 0.6715 - accuracy: 0.6467 - val_loss: 0.6515 - val_accuracy: 0.6905
# Epoch 19/150
# 167/167 [==============================] - 0s 219us/step - loss: 0.6470 - accuracy: 0.6826 - val_loss: 0.6515 - val_accuracy: 0.6667
# Epoch 20/150
# 167/167 [==============================] - 0s 235us/step - loss: 0.6654 - accuracy: 0.6647 - val_loss: 0.6593 - val_accuracy: 0.6429
# Epoch 21/150
# 167/167 [==============================] - 0s 229us/step - loss: 0.6606 - accuracy: 0.6587 - val_loss: 0.6382 - val_accuracy: 0.6905
# Epoch 22/150
# 167/167 [==============================] - 0s 232us/step - loss: 0.6363 - accuracy: 0.6587 - val_loss: 0.6309 - val_accuracy: 0.6905
# Epoch 23/150
# 167/167 [==============================] - 0s 251us/step - loss: 0.6690 - accuracy: 0.6467 - val_loss: 0.6331 - val_accuracy: 0.6905
# Epoch 24/150
# 167/167 [==============================] - 0s 259us/step - loss: 0.6614 - accuracy: 0.6467 - val_loss: 0.6386 - val_accuracy: 0.6905
# Epoch 25/150
# 167/167 [==============================] - 0s 226us/step - loss: 0.6563 - accuracy: 0.6527 - val_loss: 0.6451 - val_accuracy: 0.6667
# Epoch 26/150
# 167/167 [==============================] - 0s 221us/step - loss: 0.6435 - accuracy: 0.6826 - val_loss: 0.6603 - val_accuracy: 0.6429
# Epoch 27/150
# 167/167 [==============================] - 0s 217us/step - loss: 0.6323 - accuracy: 0.6886 - val_loss: 0.6537 - val_accuracy: 0.6429
# Epoch 28/150
# 167/167 [==============================] - 0s 222us/step - loss: 0.6355 - accuracy: 0.7126 - val_loss: 0.6546 - val_accuracy: 0.6429
# Epoch 29/150
# 167/167 [==============================] - 0s 250us/step - loss: 0.6207 - accuracy: 0.7126 - val_loss: 0.6622 - val_accuracy: 0.6190
# Epoch 30/150
# 167/167 [==============================] - 0s 234us/step - loss: 0.6344 - accuracy: 0.6946 - val_loss: 0.6466 - val_accuracy: 0.6667
# Epoch 31/150
# 167/167 [==============================] - 0s 215us/step - loss: 0.6218 - accuracy: 0.7126 - val_loss: 0.6394 - val_accuracy: 0.6905
# Epoch 32/150
# 167/167 [==============================] - 0s 237us/step - loss: 0.6574 - accuracy: 0.7066 - val_loss: 0.6530 - val_accuracy: 0.6667
# Epoch 33/150
# 167/167 [==============================] - 0s 213us/step - loss: 0.6364 - accuracy: 0.6647 - val_loss: 0.6395 - val_accuracy: 0.6667
# Epoch 34/150
# 167/167 [==============================] - 0s 304us/step - loss: 0.6360 - accuracy: 0.7066 - val_loss: 0.6389 - val_accuracy: 0.6667
# Epoch 35/150
# 167/167 [==============================] - 0s 241us/step - loss: 0.6599 - accuracy: 0.6766 - val_loss: 0.6619 - val_accuracy: 0.6190
# Epoch 36/150
# 167/167 [==============================] - 0s 274us/step - loss: 0.6260 - accuracy: 0.6886 - val_loss: 0.6384 - val_accuracy: 0.6429
# Epoch 37/150
# 167/167 [==============================] - 0s 183us/step - loss: 0.6268 - accuracy: 0.6826 - val_loss: 0.6454 - val_accuracy: 0.6667
# Epoch 38/150
# 167/167 [==============================] - 0s 184us/step - loss: 0.6218 - accuracy: 0.7006 - val_loss: 0.6696 - val_accuracy: 0.5714
# Epoch 39/150
# 167/167 [==============================] - 0s 200us/step - loss: 0.6118 - accuracy: 0.7006 - val_loss: 0.6409 - val_accuracy: 0.6429
# Epoch 40/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.6020 - accuracy: 0.7305 - val_loss: 0.6608 - val_accuracy: 0.6190
# Epoch 41/150
# 167/167 [==============================] - 0s 204us/step - loss: 0.6051 - accuracy: 0.7066 - val_loss: 0.6648 - val_accuracy: 0.5952
# Epoch 42/150
# 167/167 [==============================] - 0s 209us/step - loss: 0.6133 - accuracy: 0.7246 - val_loss: 0.6330 - val_accuracy: 0.6905
# Epoch 43/150
# 167/167 [==============================] - 0s 214us/step - loss: 0.5952 - accuracy: 0.7305 - val_loss: 0.6491 - val_accuracy: 0.6190
# Epoch 44/150
# 167/167 [==============================] - 0s 205us/step - loss: 0.6093 - accuracy: 0.6707 - val_loss: 0.6582 - val_accuracy: 0.5952
# Epoch 45/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.6371 - accuracy: 0.6467 - val_loss: 0.6712 - val_accuracy: 0.5714
# Epoch 46/150
# 167/167 [==============================] - 0s 205us/step - loss: 0.6248 - accuracy: 0.6707 - val_loss: 0.6478 - val_accuracy: 0.6429
# Epoch 47/150
# 167/167 [==============================] - 0s 221us/step - loss: 0.6086 - accuracy: 0.7126 - val_loss: 0.6515 - val_accuracy: 0.6429
# Epoch 48/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.5989 - accuracy: 0.7246 - val_loss: 0.6695 - val_accuracy: 0.5714
# Epoch 49/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.6176 - accuracy: 0.7186 - val_loss: 0.6585 - val_accuracy: 0.6429
# Epoch 50/150
# 167/167 [==============================] - 0s 206us/step - loss: 0.5830 - accuracy: 0.7605 - val_loss: 0.6696 - val_accuracy: 0.5952
# Epoch 51/150
# 167/167 [==============================] - 0s 192us/step - loss: 0.5745 - accuracy: 0.7305 - val_loss: 0.6792 - val_accuracy: 0.5952
# Epoch 52/150
# 167/167 [==============================] - 0s 238us/step - loss: 0.6424 - accuracy: 0.6766 - val_loss: 0.6643 - val_accuracy: 0.6190
# Epoch 53/150
# 167/167 [==============================] - 0s 184us/step - loss: 0.6205 - accuracy: 0.6766 - val_loss: 0.6713 - val_accuracy: 0.5952
# Epoch 54/150
# 167/167 [==============================] - 0s 185us/step - loss: 0.5820 - accuracy: 0.6946 - val_loss: 0.6744 - val_accuracy: 0.5952
# Epoch 55/150
# 167/167 [==============================] - 0s 188us/step - loss: 0.5830 - accuracy: 0.7545 - val_loss: 0.6741 - val_accuracy: 0.5952
# Epoch 56/150
# 167/167 [==============================] - 0s 183us/step - loss: 0.5909 - accuracy: 0.7425 - val_loss: 0.6770 - val_accuracy: 0.5952
# Epoch 57/150
# 167/167 [==============================] - 0s 188us/step - loss: 0.5983 - accuracy: 0.7246 - val_loss: 0.7101 - val_accuracy: 0.5000
# Epoch 58/150
# 167/167 [==============================] - 0s 184us/step - loss: 0.6171 - accuracy: 0.6826 - val_loss: 0.6516 - val_accuracy: 0.6429
# Epoch 59/150
# 167/167 [==============================] - 0s 181us/step - loss: 0.5812 - accuracy: 0.7365 - val_loss: 0.6661 - val_accuracy: 0.5952
# Epoch 60/150
# 167/167 [==============================] - 0s 202us/step - loss: 0.6093 - accuracy: 0.7365 - val_loss: 0.7141 - val_accuracy: 0.5000
# Epoch 61/150
# 167/167 [==============================] - 0s 186us/step - loss: 0.5905 - accuracy: 0.7365 - val_loss: 0.6709 - val_accuracy: 0.5952
# Epoch 62/150
# 167/167 [==============================] - 0s 216us/step - loss: 0.5974 - accuracy: 0.7365 - val_loss: 0.6654 - val_accuracy: 0.5952
# Epoch 63/150
# 167/167 [==============================] - 0s 188us/step - loss: 0.5872 - accuracy: 0.7365 - val_loss: 0.6952 - val_accuracy: 0.5714
# Epoch 64/150
# 167/167 [==============================] - 0s 198us/step - loss: 0.6102 - accuracy: 0.6766 - val_loss: 0.6894 - val_accuracy: 0.5714
# Epoch 65/150
# 167/167 [==============================] - 0s 181us/step - loss: 0.5604 - accuracy: 0.7665 - val_loss: 0.6771 - val_accuracy: 0.5952
# Epoch 66/150
# 167/167 [==============================] - 0s 209us/step - loss: 0.5585 - accuracy: 0.7365 - val_loss: 0.6683 - val_accuracy: 0.6190
# Epoch 67/150
# 167/167 [==============================] - 0s 219us/step - loss: 0.5794 - accuracy: 0.7126 - val_loss: 0.6929 - val_accuracy: 0.5714
# Epoch 68/150
# 167/167 [==============================] - 0s 238us/step - loss: 0.5803 - accuracy: 0.7365 - val_loss: 0.7070 - val_accuracy: 0.5476
# Epoch 69/150
# 167/167 [==============================] - 0s 193us/step - loss: 0.5957 - accuracy: 0.7066 - val_loss: 0.7059 - val_accuracy: 0.5476
# Epoch 70/150
# 167/167 [==============================] - 0s 197us/step - loss: 0.5751 - accuracy: 0.7485 - val_loss: 0.6746 - val_accuracy: 0.5952
# Epoch 71/150
# 167/167 [==============================] - 0s 193us/step - loss: 0.5756 - accuracy: 0.7485 - val_loss: 0.6901 - val_accuracy: 0.6190
# Epoch 72/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.5774 - accuracy: 0.7246 - val_loss: 0.6923 - val_accuracy: 0.5476
# Epoch 73/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.6061 - accuracy: 0.6826 - val_loss: 0.6892 - val_accuracy: 0.5714
# Epoch 74/150
# 167/167 [==============================] - 0s 242us/step - loss: 0.5728 - accuracy: 0.7485 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 75/150
# 167/167 [==============================] - 0s 209us/step - loss: 0.5604 - accuracy: 0.7186 - val_loss: 0.7066 - val_accuracy: 0.5000
# Epoch 76/150
# 167/167 [==============================] - 0s 287us/step - loss: 0.5659 - accuracy: 0.7246 - val_loss: 0.6835 - val_accuracy: 0.5714
# Epoch 77/150
# 167/167 [==============================] - 0s 213us/step - loss: 0.5653 - accuracy: 0.7844 - val_loss: 0.6874 - val_accuracy: 0.5714
# Epoch 78/150
# 167/167 [==============================] - 0s 216us/step - loss: 0.5627 - accuracy: 0.7126 - val_loss: 0.6893 - val_accuracy: 0.5476
# Epoch 79/150
# 167/167 [==============================] - 0s 272us/step - loss: 0.5808 - accuracy: 0.7485 - val_loss: 0.6939 - val_accuracy: 0.5238
# Epoch 80/150
# 167/167 [==============================] - 0s 219us/step - loss: 0.5725 - accuracy: 0.7126 - val_loss: 0.7131 - val_accuracy: 0.4762
# Epoch 81/150
# 167/167 [==============================] - 0s 216us/step - loss: 0.5693 - accuracy: 0.7365 - val_loss: 0.6441 - val_accuracy: 0.6667
# Epoch 82/150
# 167/167 [==============================] - 0s 272us/step - loss: 0.5900 - accuracy: 0.6946 - val_loss: 0.6510 - val_accuracy: 0.6190
# Epoch 83/150
# 167/167 [==============================] - 0s 215us/step - loss: 0.6099 - accuracy: 0.7305 - val_loss: 0.7128 - val_accuracy: 0.4762
# Epoch 84/150
# 167/167 [==============================] - 0s 206us/step - loss: 0.5330 - accuracy: 0.7665 - val_loss: 0.6848 - val_accuracy: 0.5476
# Epoch 85/150
# 167/167 [==============================] - 0s 196us/step - loss: 0.5547 - accuracy: 0.7665 - val_loss: 0.6730 - val_accuracy: 0.6190
# Epoch 86/150
# 167/167 [==============================] - 0s 234us/step - loss: 0.5796 - accuracy: 0.7186 - val_loss: 0.6964 - val_accuracy: 0.5238
# Epoch 87/150
# 167/167 [==============================] - 0s 193us/step - loss: 0.5384 - accuracy: 0.7485 - val_loss: 0.6878 - val_accuracy: 0.5476
# Epoch 88/150
# 167/167 [==============================] - 0s 199us/step - loss: 0.5295 - accuracy: 0.7784 - val_loss: 0.6766 - val_accuracy: 0.6190
# Epoch 89/150
# 167/167 [==============================] - 0s 235us/step - loss: 0.5654 - accuracy: 0.7365 - val_loss: 0.7098 - val_accuracy: 0.5000
# Epoch 90/150
# 167/167 [==============================] - 0s 197us/step - loss: 0.5458 - accuracy: 0.7186 - val_loss: 0.6847 - val_accuracy: 0.6190
# Epoch 91/150
# 167/167 [==============================] - 0s 207us/step - loss: 0.5729 - accuracy: 0.7365 - val_loss: 0.6687 - val_accuracy: 0.6429
# Epoch 92/150
# 167/167 [==============================] - 0s 202us/step - loss: 0.5604 - accuracy: 0.7844 - val_loss: 0.7229 - val_accuracy: 0.4762
# Epoch 93/150
# 167/167 [==============================] - 0s 231us/step - loss: 0.5467 - accuracy: 0.7365 - val_loss: 0.7085 - val_accuracy: 0.5000
# Epoch 94/150
# 167/167 [==============================] - 0s 241us/step - loss: 0.5296 - accuracy: 0.7425 - val_loss: 0.6562 - val_accuracy: 0.6190
# Epoch 95/150
# 167/167 [==============================] - 0s 178us/step - loss: 0.5722 - accuracy: 0.7844 - val_loss: 0.7059 - val_accuracy: 0.5000
# Epoch 96/150
# 167/167 [==============================] - 0s 266us/step - loss: 0.5345 - accuracy: 0.7126 - val_loss: 0.6832 - val_accuracy: 0.6190
# Epoch 97/150
# 167/167 [==============================] - 0s 187us/step - loss: 0.5758 - accuracy: 0.7186 - val_loss: 0.7019 - val_accuracy: 0.4762
# Epoch 98/150
# 167/167 [==============================] - 0s 171us/step - loss: 0.5438 - accuracy: 0.7605 - val_loss: 0.7267 - val_accuracy: 0.4762
# Epoch 99/150
# 167/167 [==============================] - 0s 201us/step - loss: 0.5448 - accuracy: 0.7365 - val_loss: 0.6612 - val_accuracy: 0.6429
# Epoch 100/150
# 167/167 [==============================] - 0s 198us/step - loss: 0.5338 - accuracy: 0.7904 - val_loss: 0.7081 - val_accuracy: 0.4524
# Epoch 101/150
# 167/167 [==============================] - 0s 228us/step - loss: 0.5720 - accuracy: 0.6946 - val_loss: 0.6955 - val_accuracy: 0.5714
# Epoch 102/150
# 167/167 [==============================] - 0s 222us/step - loss: 0.5654 - accuracy: 0.7545 - val_loss: 0.6994 - val_accuracy: 0.5000
# Epoch 103/150
# 167/167 [==============================] - 0s 257us/step - loss: 0.5277 - accuracy: 0.7305 - val_loss: 0.6955 - val_accuracy: 0.5714
# Epoch 104/150
# 167/167 [==============================] - 0s 207us/step - loss: 0.5720 - accuracy: 0.7305 - val_loss: 0.6863 - val_accuracy: 0.6190
# Epoch 105/150
# 167/167 [==============================] - 0s 181us/step - loss: 0.5431 - accuracy: 0.7725 - val_loss: 0.7213 - val_accuracy: 0.4762
# Epoch 106/150
# 167/167 [==============================] - 0s 233us/step - loss: 0.5621 - accuracy: 0.7365 - val_loss: 0.7035 - val_accuracy: 0.5476
# Epoch 107/150
# 167/167 [==============================] - 0s 253us/step - loss: 0.5574 - accuracy: 0.7485 - val_loss: 0.7008 - val_accuracy: 0.5952
# Epoch 108/150
# 167/167 [==============================] - 0s 246us/step - loss: 0.5207 - accuracy: 0.7485 - val_loss: 0.6973 - val_accuracy: 0.5952
# Epoch 109/150
# 167/167 [==============================] - 0s 191us/step - loss: 0.5691 - accuracy: 0.7485 - val_loss: 0.7022 - val_accuracy: 0.5952
# Epoch 110/150
# 167/167 [==============================] - 0s 201us/step - loss: 0.5326 - accuracy: 0.7605 - val_loss: 0.7050 - val_accuracy: 0.5476
# Epoch 111/150
# 167/167 [==============================] - 0s 195us/step - loss: 0.5278 - accuracy: 0.7545 - val_loss: 0.6901 - val_accuracy: 0.5714
# Epoch 112/150
# 167/167 [==============================] - 0s 221us/step - loss: 0.5672 - accuracy: 0.7126 - val_loss: 0.7083 - val_accuracy: 0.5000
# Epoch 113/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.5445 - accuracy: 0.7605 - val_loss: 0.6953 - val_accuracy: 0.5714
# Epoch 114/150
# 167/167 [==============================] - 0s 187us/step - loss: 0.5239 - accuracy: 0.7725 - val_loss: 0.7010 - val_accuracy: 0.5238
# Epoch 115/150
# 167/167 [==============================] - 0s 179us/step - loss: 0.5868 - accuracy: 0.7126 - val_loss: 0.6925 - val_accuracy: 0.5714
# Epoch 116/150
# 167/167 [==============================] - 0s 220us/step - loss: 0.5277 - accuracy: 0.7605 - val_loss: 0.6964 - val_accuracy: 0.5714
# Epoch 117/150
# 167/167 [==============================] - 0s 210us/step - loss: 0.5149 - accuracy: 0.7784 - val_loss: 0.7337 - val_accuracy: 0.4762
# Epoch 118/150
# 167/167 [==============================] - 0s 246us/step - loss: 0.5132 - accuracy: 0.7844 - val_loss: 0.6939 - val_accuracy: 0.5952
# Epoch 119/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.5292 - accuracy: 0.7246 - val_loss: 0.6960 - val_accuracy: 0.5952
# Epoch 120/150
# 167/167 [==============================] - 0s 203us/step - loss: 0.5644 - accuracy: 0.7545 - val_loss: 0.6581 - val_accuracy: 0.6190
# Epoch 121/150
# 167/167 [==============================] - 0s 252us/step - loss: 0.5392 - accuracy: 0.7904 - val_loss: 0.7429 - val_accuracy: 0.4762
# Epoch 122/150
# 167/167 [==============================] - 0s 210us/step - loss: 0.5210 - accuracy: 0.7545 - val_loss: 0.6925 - val_accuracy: 0.6190
# Epoch 123/150
# 167/167 [==============================] - 0s 239us/step - loss: 0.5203 - accuracy: 0.7784 - val_loss: 0.7062 - val_accuracy: 0.5238
# Epoch 124/150
# 167/167 [==============================] - 0s 215us/step - loss: 0.5130 - accuracy: 0.7545 - val_loss: 0.7123 - val_accuracy: 0.5000
# Epoch 125/150
# 167/167 [==============================] - 0s 199us/step - loss: 0.5457 - accuracy: 0.7665 - val_loss: 0.6987 - val_accuracy: 0.6190
# Epoch 126/150
# 167/167 [==============================] - 0s 204us/step - loss: 0.5258 - accuracy: 0.7545 - val_loss: 0.7071 - val_accuracy: 0.5476
# Epoch 127/150
# 167/167 [==============================] - 0s 210us/step - loss: 0.5362 - accuracy: 0.7545 - val_loss: 0.6791 - val_accuracy: 0.5952
# Epoch 128/150
# 167/167 [==============================] - 0s 207us/step - loss: 0.5414 - accuracy: 0.7665 - val_loss: 0.7331 - val_accuracy: 0.4762
# Epoch 129/150
# 167/167 [==============================] - 0s 195us/step - loss: 0.5186 - accuracy: 0.7365 - val_loss: 0.7227 - val_accuracy: 0.5000
# Epoch 130/150
# 167/167 [==============================] - 0s 216us/step - loss: 0.5312 - accuracy: 0.7425 - val_loss: 0.6748 - val_accuracy: 0.6190
# Epoch 131/150
# 167/167 [==============================] - 0s 202us/step - loss: 0.4969 - accuracy: 0.8084 - val_loss: 0.7499 - val_accuracy: 0.4524
# Epoch 132/150
# 167/167 [==============================] - 0s 218us/step - loss: 0.5477 - accuracy: 0.7246 - val_loss: 0.6727 - val_accuracy: 0.6190
# Epoch 133/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.5532 - accuracy: 0.7784 - val_loss: 0.6883 - val_accuracy: 0.5714
# Epoch 134/150
# 167/167 [==============================] - 0s 207us/step - loss: 0.5563 - accuracy: 0.7485 - val_loss: 0.7417 - val_accuracy: 0.4762
# Epoch 135/150
# 167/167 [==============================] - 0s 208us/step - loss: 0.5502 - accuracy: 0.7126 - val_loss: 0.6929 - val_accuracy: 0.5952
# Epoch 136/150
# 167/167 [==============================] - 0s 214us/step - loss: 0.5425 - accuracy: 0.7485 - val_loss: 0.7148 - val_accuracy: 0.5000
# Epoch 137/150
# 167/167 [==============================] - 0s 247us/step - loss: 0.5497 - accuracy: 0.7425 - val_loss: 0.6840 - val_accuracy: 0.5714
# Epoch 138/150
# 167/167 [==============================] - 0s 210us/step - loss: 0.5611 - accuracy: 0.7725 - val_loss: 0.7019 - val_accuracy: 0.5714
# Epoch 139/150
# 167/167 [==============================] - 0s 202us/step - loss: 0.4939 - accuracy: 0.7665 - val_loss: 0.7485 - val_accuracy: 0.4762
# Epoch 140/150
# 167/167 [==============================] - 0s 220us/step - loss: 0.5263 - accuracy: 0.7784 - val_loss: 0.7046 - val_accuracy: 0.5238
# Epoch 141/150
# 167/167 [==============================] - 0s 233us/step - loss: 0.5394 - accuracy: 0.7425 - val_loss: 0.7018 - val_accuracy: 0.5238
# Epoch 142/150
# 167/167 [==============================] - 0s 250us/step - loss: 0.5196 - accuracy: 0.7725 - val_loss: 0.7292 - val_accuracy: 0.5000
# Epoch 143/150
# 167/167 [==============================] - 0s 267us/step - loss: 0.5406 - accuracy: 0.7545 - val_loss: 0.7049 - val_accuracy: 0.5000
# Epoch 144/150
# 167/167 [==============================] - 0s 198us/step - loss: 0.5074 - accuracy: 0.7964 - val_loss: 0.7061 - val_accuracy: 0.5000
# Epoch 145/150
# 167/167 [==============================] - 0s 250us/step - loss: 0.5425 - accuracy: 0.7545 - val_loss: 0.7152 - val_accuracy: 0.4762
# Epoch 146/150
# 167/167 [==============================] - 0s 256us/step - loss: 0.5087 - accuracy: 0.7605 - val_loss: 0.7071 - val_accuracy: 0.5000
# Epoch 147/150
# 167/167 [==============================] - 0s 170us/step - loss: 0.4995 - accuracy: 0.8084 - val_loss: 0.7076 - val_accuracy: 0.5000
# Epoch 148/150
# 167/167 [==============================] - 0s 209us/step - loss: 0.5367 - accuracy: 0.7784 - val_loss: 0.6926 - val_accuracy: 0.5714
# Epoch 149/150
# 167/167 [==============================] - 0s 195us/step - loss: 0.5356 - accuracy: 0.7485 - val_loss: 0.7035 - val_accuracy: 0.5238
# Epoch 150/150
# 167/167 [==============================] - 0s 223us/step - loss: 0.5326 - accuracy: 0.7365 - val_loss: 0.6960 - val_accuracy: 0.5476

# %% [markdown]
# ## Learning Curves

# %% [markdown]
# __Question__: How to use Learning Curves to Diagnose Machine Learning Model Performance?

# %% [markdown]
# This lecture aim is to define and study an important tool for diagnostic of a machine learning algorithm: __learning curves__.
#
# > A learning curve is a plot of model learning performance over experience or time.
#
# In other words, one can say that _Learning Curves_ provide a mathematical representation of the learning process that takes place as task repetition occurs.

# %% [markdown]
# The model can be evaluated on the training dataset and on a hold out validation dataset after each update during training and plots of the measured performance can created to show learning curves.
#
# Reviewing learning curves of models during training can be used to diagnose problems with learning, such as an underfit or overfit model, as well as whether the training and validation datasets are suitably representative.

# %% [markdown]
# An interesting, but quite technical, reading may be found [here](https://www.sciencedirect.com/science/article/abs/pii/S016981411100062X).

# %% [markdown]
# First of all we need to choose a way to parametrise the learning performance.
# This is done through a metric. One can be, for instance, the learning accuracy, or precision, etc.

# %%
print(history.history.keys())

plt.figure(figsize=(15,10))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.figure(figsize=(15,10))
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 50/50 [==============================] - 0s 506us/step
#
# # Evaluate
# {'loss': 0.6243054866790771, 'accuracy': 0.699999988079071}

# %% [markdown]
# ## Test with your picture

# %%
my_image = "Giampiero.jpeg" # change this to the name of your image file 
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)

fname = "images/" + my_image
image = np.array(imageio.imread(fname))
image = image/255.
my_image = skimage.transform.resize(image, (num_px,num_px)).reshape((1, num_px*num_px*3))
my_predicted_image = model.predict(my_image)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.round(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# y = 0.5710428, your L-layer model predicts a "cat" picture.
