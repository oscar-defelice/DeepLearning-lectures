# %% [markdown]
# ![](https://www.domsoria.com/wp-content/uploads/2019/11/keras.png)

# %% [markdown]
# # Deep Neural Network for Image Classification: Application
#
# We will build a deep network, and apply it to cat vs non-cat classification. Hopefully, you will see an improvement in accuracy relative to your previous logistic regression implementation.
#
# **After this assignment you will be able to:**
# - Build and apply a deep neural network to supervised learning.
#
# Let's get started!

# %%
# Import libraries
import time
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from utils.dnn_app_utils_v3 import *
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import vis_utils, plot_model
from keras import optimizers
import pydotplus, pydot
vis_utils.pydot = pydot


import skimage
import imageio

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
# Out:
# Using TensorFlow backend.
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## The dataset
#
# **Problem Statement**: You are given a dataset ("data.h5") containing:
#     - a training set of m_train images labelled as cat (1) or non-cat (0)
#     - a test set of m_test images labelled as cat and non-cat
#     - each image is of shape (num_px, num_px, 3) where 3 is for the 3 channels (RGB).
#
# Let's get more familiar with the dataset. Load the data by running the cell below.

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %% [markdown]
# The following code will show you an image in the dataset. Feel free to change the index and re-run the cell multiple times to see other images.

# %%
# Example of a picture
index = 10
plt.imshow(train_x_orig[index])
print ("y = " + str(train_y[0,index]) + ". It's a " + classes[train_y[0,index]].decode("utf-8") +  " picture.")
# Out:
# y = 0. It's a non-cat picture.

# %% [markdown]
# ## The model
#
# **Problem Statement**: How to create a neural network model in Keras?
#
# Well, there are several ways. Let's try to get familiar with a very intuitive one.
#
# ### A warm-up problem
#
# Before classifiyin a cat image, we can study a simpler problem: classify whether a patient may be result in having diabete. The dataset describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# Attributes are numeric valued, so we can feed a neural network directly with them.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv', header=None)
col_names = [   'NumberPregnant',
                'PlasmaGlucoseConc',
                'BloodPressure',
                'TricepsSkinThickness',
                'InsulinConc',
                'BMI',
                'DiabetesFunc',
                'Age',
                'Target']

df.columns = col_names

# %%
df
# Out:
#      NumberPregnant  PlasmaGlucoseConc  BloodPressure  TricepsSkinThickness  \
# 0                 6                148             72                    35
# 1                 1                 85             66                    29
# 2                 8                183             64                     0
# 3                 1                 89             66                    23
# 4                 0                137             40                    35
# ..              ...                ...            ...                   ...
# 763              10                101             76                    48
# 764               2                122             70                    27
# 765               5                121             72                    23
# 766               1                126             60                     0
# 767               1                 93             70                    31
#
#      InsulinConc   BMI  DiabetesFunc  Age  Target
# 0              0  33.6         0.627   50       1
# 1              0  26.6         0.351   31       0
# 2              0  23.3         0.672   32       1
# 3             94  28.1         0.167   21       0
# 4            168  43.1         2.288   33       1
# ..           ...   ...           ...  ...     ...
# 763          180  32.9         0.171   63       0
# 764            0  36.8         0.340   27       0
# 765          112  26.2         0.245   30       0
# 766            0  30.1         0.349   47       1
# 767            0  30.4         0.315   23       0
#
# [768 rows x 9 columns]

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
#
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the `input_dim` argument and setting it to $8$ for the $8$ input variables.
#
# > How do we know the number of layers and their types?
#
# This is a very hard question.
#
# __Here__: In this example, we will use a fully-connected network structure with three layers.

# %% [markdown]
# #### Activation Functions

# %% [markdown]
# Activation functions are functions used to get the output of a node
#
# ![](https://miro.medium.com/max/2724/1*E7ulOdTP-yekFGIJ8H8eVw.png)
#
# it must be __non-linear__, indeed one can prove that a very deep network is equivalent to just one-node network if you use only linear activation functions.
#
# __Commonly used activation functions__

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*p_hyqAtyI8pbt2kEl6siOQ.png)

# %% [markdown]
# **General notes**
#
# Briefly, functions that have a bit **flatter S** shape have better discriminatory power. The main reason why log-sigmoid and tanh are used is that their calculus derivatives, which are needed by the most common training algorithm back-propagation, are computationally convenient to compute.
#
# *For this problem*: we use a three-layers network, with `relu` activation for the first two layers' units, while `sigmoid` for the output layer.

# %%
model = Sequential(name = 'diabete_model')
model.add(Dense(units=12, input_dim=8, activation = 'relu', name = 'first_layer'))
model.add(Dense(units=5, activation = 'relu', name = 'second_layer'))
model.add(Dense(units=1, activation = 'sigmoid', name = 'output_layer'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "diabete_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# first_layer (Dense)          (None, 12)                108
# _________________________________________________________________
# second_layer (Dense)         (None, 5)                 65
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 6
# =================================================================
# Total params: 179
# Trainable params: 179
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# You can also visualise the model on a picture.

# %%
plot_model(model,show_shapes=True, show_layer_names=True, to_file='model.png')

# %% [markdown]
# `None` is there to indicate the number of training examples.
# As one can see the model takes in a tensor of shape `(None, 8)`, since we have $8$ features.
#
# We are now ready to prepare data to be fed in the model.

# %%
# Transform data into array
X = df[df.columns[:8]].values
Y = df[df.columns[-1]].values.reshape(-1,1)

# %% [markdown]
# Split into train and test set

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.10, random_state=42)

X_val = X_train[:28]
Y_val = Y_train[:28]
X_train = X_train[28:]
Y_train = Y_train[28:]

# %%
print('# Fit model on training data')
history = model.fit(X_train, Y_train,
                    batch_size=10,
                    epochs=150,
                    # We pass some validation for
                    # monitoring validation loss and metrics
                    # at the end of each epoch
                    validation_data=(X_val, Y_val))

print('\nhistory dict:', history.history)
# Out:
# # Fit model on training data
# WARNING:tensorflow:From /home/martina/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 663 samples, validate on 28 samples
# Epoch 1/150
# 663/663 [==============================] - 0s 255us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 2/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 3/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 4/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 5/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 6/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 7/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 8/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 9/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 10/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 11/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 12/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 13/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 14/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 15/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 16/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 17/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 18/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 19/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 20/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 21/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 22/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 23/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 24/150
# 663/663 [==============================] - 0s 92us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 25/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 26/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 27/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 28/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 29/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 30/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 31/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 32/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 33/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 34/150
# 663/663 [==============================] - 0s 103us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 35/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 36/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 37/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 38/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 39/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 40/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 41/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 42/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 43/150
# 663/663 [==============================] - 0s 101us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 44/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 45/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 46/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 47/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 48/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 49/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 50/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 51/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 52/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 53/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 54/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 55/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 56/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 57/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 58/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 59/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 60/150
# 663/663 [==============================] - 0s 102us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 61/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 62/150
# 663/663 [==============================] - 0s 103us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 63/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 64/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 65/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 66/150
# 663/663 [==============================] - 0s 101us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 67/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 68/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 69/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 70/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 71/150
# 663/663 [==============================] - 0s 103us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 72/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 73/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 74/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 75/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 76/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 77/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 78/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 79/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 80/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 81/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 82/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 83/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 84/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 85/150
# 663/663 [==============================] - 0s 89us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 86/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 87/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 88/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 89/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 90/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 91/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 92/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 93/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 94/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 95/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 96/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 97/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 98/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 99/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 100/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 101/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 102/150
# 663/663 [==============================] - 0s 102us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 103/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 104/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 105/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 106/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 107/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 108/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 109/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 110/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 111/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 112/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 113/150
# 663/663 [==============================] - 0s 101us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 114/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 115/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 116/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 117/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 118/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 119/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 120/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 121/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 122/150
# 663/663 [==============================] - 0s 92us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 123/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 124/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 125/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 126/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 127/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 128/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 129/150
# 663/663 [==============================] - 0s 101us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 130/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 131/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 132/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 133/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 134/150
# 663/663 [==============================] - 0s 100us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 135/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 136/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 137/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 138/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 139/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 140/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 141/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 142/150
# 663/663 [==============================] - 0s 98us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 143/150
# 663/663 [==============================] - 0s 93us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 144/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 145/150
# 663/663 [==============================] - 0s 99us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 146/150
# 663/663 [==============================] - 0s 97us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 147/150
# 663/663 [==============================] - 0s 96us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 148/150
# 663/663 [==============================] - 0s 95us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 149/150
# 663/663 [==============================] - 0s 103us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
# Epoch 150/150
# 663/663 [==============================] - 0s 94us/step - loss: 5.6401 - accuracy: 0.6501 - val_loss: 5.1808 - val_accuracy: 0.6786
#
# history dict: {'val_loss': [5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858, 5.180816275732858], 'val_accuracy': [0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.6785714030265808, 0.67 ...

# %% [markdown]
# #### Evaluate

# %%
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, Y_test)
print('test loss, test acc:', results)
# Out:
# # Evaluate on test data
# 77/77 [==============================] - 0s 16us/step
# test loss, test acc: [5.651799669513455, 0.649350643157959]

# %% [markdown]
# #### Predictions
#
# The number one question I get asked is:
#
# > After I train my model, how can I use it to make predictions on new data?
#
# this is a great question.

# %%
# make probability predictions with the model
new_patient = np.array([4.00e+00, 1.48e+02, 6.00e+01, 2.70e+01, 3.18e+02, 3.09e+01,
       1.50e-01, 2.90e+01]).reshape(1,-1)

prob_pred = model.predict(new_patient)

prediction = round(float(prob_pred[[0]]))

# %%
prob_pred
# Out:
# array([[0.]], dtype=float32)

# %% [markdown]
# ## Back to cats

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()

# %%
# Explore your dataset 
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(train_x_orig.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x_orig shape: " + str(test_x_orig.shape))
print ("test_y shape: " + str(test_y.shape))
# Out:
# Number of training examples: 209
# Number of testing examples: 50
# Each image is of size: (64, 64, 3)
# train_x_orig shape: (209, 64, 64, 3)
# train_y shape: (1, 209)
# test_x_orig shape: (50, 64, 64, 3)
# test_y shape: (1, 50)

# %% [markdown]
# As usual, you reshape and standardize the images before feeding them to the network. The code is given in the cell below.
#
# <img src="images/imvectorkiank.png" style="width:450px;height:300px;">
#
# <caption><center> <u>Figure 1</u>: Image to vector conversion. <br> </center></caption>

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1)   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1)

# Standardize data to have feature values between 0 and 1.
train_x = (train_x_flatten/255.)
test_x = (test_x_flatten/255.)

print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
# Out:
# train_x's shape: (209, 12288)
# test_x's shape: (50, 12288)

# %% [markdown]
# $12,288$ equals $64 \times 64 \times 3$ which is the size of one reshaped image vector.

# %% [markdown]
# ## The model

# %% [markdown]
# Now that you are familiar with the dataset, it is time to build a deep neural network to distinguish cat images from non-cat images.
#
# You will build two different models:
# - A 2-layer neural network
# - An L-layer deep neural network
#
# You will then compare the performance of these models, and also try out different values for $L$.
#
# Let's look at the two architectures.
#
# ### 2-layer neural network
#
# <img src="images/2layerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 2</u>: 2-layer neural network. <br> The model can be summarized as: ***INPUT -> LINEAR -> RELU -> LINEAR -> SIGMOID -> OUTPUT***. </center></caption>
#
# <u>Detailed Architecture of figure 2</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size $(12288,1)$.
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ of size $(n^{[1]}, 12288)$.
# - You then add a bias term and take its relu to get the following vector: $[a_0^{[1]}, a_1^{[1]},..., a_{n^{[1]}-1}^{[1]}]^T$.
# - You then repeat the same process.
# - You multiply the resulting vector by $W^{[2]}$ and add your intercept (bias).
# - Finally, you take the sigmoid of the result. If it is greater than 0.5, you classify it to be a cat.
#
# ###  L-layer deep neural network
#
# It is hard to represent an L-layer deep neural network with the above representation. However, here is a simplified network representation:
#
# <img src="images/LlayerNN_kiank.png" style="width:650px;height:400px;">
# <caption><center> <u>Figure 3</u>: L-layer neural network. <br> The model can be summarized as: ***[LINEAR -> RELU] $\times$ (L-1) -> LINEAR -> SIGMOID***</center></caption>
#
# <u>Detailed Architecture of figure 3</u>:
# - The input is a (64,64,3) image which is flattened to a vector of size (12288,1).
# - The corresponding vector: $[x_0,x_1,...,x_{12287}]^T$ is then multiplied by the weight matrix $W^{[1]}$ and then you add the intercept $b^{[1]}$. The result is called the linear unit.
# - Next, you take the relu of the linear unit. This process could be repeated several times for each $(W^{[l]}, b^{[l]})$ depending on the model architecture.
# - Finally, you take the sigmoid of the final linear unit. If it is greater than 0.5, you classify it to be a cat.
#
# ### 3.3 - General methodology
#
# As usual you will follow the Keras/Deep Learning methodology to build the model:
#     1. Design the shape of your model
#     2. Add layers to your `Sequential model`
#     3. Train the parameters on the training set
#     4. Use learnt parameters to make predictions on new data.
#
# Let's now implement those two models!

# %%
n_x = 12288     # num_px * num_px * 3

# %%
def two_layer_model(n_units_1, n_units_2 = 1):
    """
        function to define a two-layer neural network model.
        
        Parameters:
        ----------
            - n_units_1 : int
                            number of hidden units of the first hidden layer.
                            
            - n_units_2 : int
                            number of hidden units of the second hidden layer.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units_1, input_dim=n_x, activation = 'tanh', kernel_initializer='uniform', name = 'first_hidden_layer'))
    model.add(Dense(n_units_2, activation = 'sigmoid', name = 'output_layer'))
    
    return model

# %%
model = two_layer_model(7)

# %%
opt = optimizers.Adam(lr = 1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# first_hidden_layer (Dense)   (None, 7)                 86023
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 8
# =================================================================
# Total params: 86,031
# Trainable params: 86,031
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_y = train_y.T

# %%
model.fit(train_x, train_y, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 209/209 [==============================] - 0s 523us/step - loss: 0.6701 - accuracy: 0.6316
# Epoch 2/100
# 209/209 [==============================] - 0s 150us/step - loss: 0.6618 - accuracy: 0.6411
# Epoch 3/100
# 209/209 [==============================] - 0s 152us/step - loss: 0
#        [0.5451297 ],
#        [0.11848485],
#        [0.20123062],
#        [0.41165137],
#        [0.70343393],
#        [0.6675515 ],
#        [0.2859289 ],
#        [0.32451096],
#        [0.32932162],
#        [0.68746406],
#        [0.3717387 ],
#        [0.6342122 ],
#        [0.3068376 ],
#        [0.30186856],
#        [0.44332626],
#        [0.18948475],
#        [0.2744791 ],
#        [0.5829887 ],
#        [0.6423099 ],
#        [0.15291831],
#        [0.3976346 ],
#        [0.5587823 ],
#        [0.50026065],
#        [0.15227887],
#        [0.77884465],
#        [0.34111792],
#        [0.21917859],
#        [0.71734613],
#        [0.5281658 ],
#        [0.32514977]], dtype=float32)

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 50/50 [==============================] - 0s 396us/step
#
# # Evaluate
# {'loss': 0.7103009009361267, 'accuracy': 0.6200000047683716}

# %% [markdown]
# ### L-layer model

# %%
def L_layer_model(n_layers, n_units, n_x):
    """
        function to define an L-layer neural network model.
        
        Parameters:
        ----------
            - n_layers : int
                            number of hidden layers + output layer.
                            
            - n_units :  list of int
                            number of hidden units of for each hidden layer.
                            
            - n_x : int
                        number of input features.
                            
        Return:
        -------
            - model : Keras model object.
            
    """
    
    model = Sequential()
    model.add(Dense(n_units[0], input_dim = n_x, activation = 'relu',  kernel_initializer='uniform')) # first layer
    for l in range(1,n_layers):
        if l == n_layers-1:
            model.add(Dropout(rate=0.5))
            model.add(Dense(n_units[l], activation = 'sigmoid', name = 'output_layer')) # output layer
        else:
            model.add(Dense(n_units[l], activation = 'relu', name = 'hidden_layer_' + str(l)))
        
    return model

# %%
n_layers = 3
n_units = [10, 5, 1]

model = L_layer_model(n_layers, n_units, n_x)

# %%
opt = optimizers.Adam(lr=1e-4)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                122890
# _________________________________________________________________
# hidden_layer_1 (Dense)       (None, 5)                 55
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 6
# =================================================================
# Total params: 122,951
# Trainable params: 122,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_x, train_y, batch_size=32, epochs=150, validation_split=0.2)
# Out:
# Train on 167 samples, validate on 42 samples
# Epoch 1/150
# 167/167 [==============================] - 0s 901us/step - loss: 0.7139 - accuracy: 0.6168 - val_loss: 0.6099 - val_accuracy: 0.7143
# Epoch 2/150
# 167/167 [==============================] - 0s 110us/step - loss: 0.6797 - accuracy: 0.6228 - val_loss: 0.6491 - val_accuracy: 0.6667
# Epoch 3/150
# 167/167 [==============================] - 0s 103us/step - loss: 0.7021 - accuracy: 0.6228 - val_loss: 0.6425 - val_accuracy: 0.6905
# Epoch 4/150
# 167/167 [==============================] - 0s 108us/step - loss: 0.6898 - accuracy: 0.6347 - val_loss: 0.6415 - val_accuracy: 0.7143
# Epoch 5/150
# 167/167 [==============================] - 0s 113us/step - loss: 0.6743 - accuracy: 0.6467 - val_loss: 0.6274 - val_accuracy: 0.7143
# Epoch 6/150
# 167/167 [==============================] - 0s 112us/step - loss: 0.6564 - accuracy: 0.6347 - val_loss: 0.6012 - val_accuracy: 0.7143
# Epoch 7/150
# 167/167 [==============================] - 0s 112us/step - loss: 0.6835 - accuracy: 0.6108 - val_loss: 0.6199 - val_accuracy: 0.7143
# Epoch 8/150
# 167/167 [==============================] - 0s 107us/step - loss: 0.6577 - accuracy: 0.6467 - val_loss: 0.6542 - val_accuracy: 0.6905
# Epoch 9/150
# 167/167 [==============================] - 0s 104us/step - loss: 0.6491 - accuracy: 0.6347 - val_loss: 0.6548 - val_accuracy: 0.6667
# Epoch 10/150
# 167/167 [==============================] - 0s 96us/step - loss: 0.6415 - accuracy: 0.6108 - val_loss: 0.6426 - val_accuracy: 0.6905
# Epoch 11/150
# 167/167 [==============================] - 0s 103us/step - loss: 0
150
# 167/167 [==============================] - 0s 111us/step - loss: 0.4163 - accuracy: 0.7485 - val_loss: 0.7015 - val_accuracy: 0.5714
# Epoch 143/150
# 167/167 [==============================] - 0s 110us/step - loss: 0.3781 - accuracy: 0.7485 - val_loss: 0.7077 - val_accuracy: 0.5952
# Epoch 144/150
# 167/167 [==============================] - 0s 105us/step - loss: 0.4212 - accuracy: 0.7665 - val_loss: 0.7151 - val_accuracy: 0.5476
# Epoch 145/150
# 167/167 [==============================] - 0s 95us/step - loss: 0.4101 - accuracy: 0.7246 - val_loss: 0.7177 - val_accuracy: 0.5476
# Epoch 146/150
# 167/167 [==============================] - 0s 105us/step - loss: 0.4053 - accuracy: 0.7844 - val_loss: 0.7157 - val_accuracy: 0.5952
# Epoch 147/150
# 167/167 [==============================] - 0s 105us/step - loss: 0.3920 - accuracy: 0.7365 - val_loss: 0.7099 - val_accuracy: 0.5476
# Epoch 148/150
# 167/167 [==============================] - 0s 111us/step - loss: 0.4030 - accuracy: 0.7844 - val_loss: 0.7423 - val_accuracy: 0.5714
# Epoch 149/150
# 167/167 [==============================] - 0s 106us/step - loss: 0.3870 - accuracy: 0.7844 - val_loss: 0.7255 - val_accuracy: 0.5476
# Epoch 150/150
# 167/167 [==============================] - 0s 107us/step - loss: 0.4345 - accuracy: 0.7605 - val_loss: 0.7053 - val_accuracy: 0.5476

# %% [markdown]
# ## Learning Curves

# %% [markdown]
# __Question__: How to use Learning Curves to Diagnose Machine Learning Model Performance?

# %% [markdown]
# This lecture aim is to define and study an important tool for diagnostic of a machine learning algorithm: __learning curves__.
#
# > A learning curve is a plot of model learning performance over experience or time.
#
# In other words, one can say that _Learning Curves_ provide a mathematical representation of the learning process that takes place as task repetition occurs.

# %% [markdown]
# The model can be evaluated on the training dataset and on a hold out validation dataset after each update during training and plots of the measured performance can created to show learning curves.
#
# Reviewing learning curves of models during training can be used to diagnose problems with learning, such as an underfit or overfit model, as well as whether the training and validation datasets are suitably representative.

# %% [markdown]
# An interesting, but quite technical, reading may be found [here](https://www.sciencedirect.com/science/article/abs/pii/S016981411100062X).

# %% [markdown]
# First of all we need to choose a way to parametrise the learning performance.
# This is done through a metric. One can be, for instance, the learning accuracy, or precision, etc.

# %%
print(history.history.keys())

plt.figure(figsize=(15,10))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.figure(figsize=(15,10))
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
res = model.evaluate(test_x, test_y.T)
print('\n# Evaluate')
dict(zip(model.metrics_names, res))
# Out:
# 50/50 [==============================] - 0s 62us/step
#
# # Evaluate
# {'loss': 0.6209022092819214, 'accuracy': 0.7400000095367432}

# %% [markdown]
# You obtained a classifier for cat picture with a $70$% accuracy.

# %% [markdown]
# ## Test with your picture

# %%
my_image = "Giampiero.jpeg" # change this to the name of your image file 
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)

fname = "images/" + my_image
image = np.array(imageio.imread(fname))
image = image/255.
my_image = skimage.transform.resize(image, (num_px,num_px)).reshape((1, num_px*num_px*3))
my_predicted_image = model.predict(my_image)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.round(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# y = 0.66680336, your L-layer model predicts a "cat" picture.
